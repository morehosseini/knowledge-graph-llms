# %% [markdown]
# **Note:** This notebook is intended for Google Colab. Mount Drive or otherwise make your graph files available before running.

# %% [markdown]
# # Step 1: Environment Setup

# %%
# Step 1: Install and import necessary libraries
# We use !pip to install packages in the Google Colab environment.

# !pip install networkx==3.2.1
# !pip install matplotlib==3.8.2
# !pip install seaborn==0.13.1
# !pip install pandas==2.2.1

# Import the libraries for use in our script
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set some default styles for our plots for better aesthetics
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14

print("All libraries installed and imported successfully.")
print(f"NetworkX version: {nx.__version__}")
# Out:
# Requirement already satisfied: networkx==3.2.1 in /usr/local/lib/python3.11/dist-packages (3.2.1)
# Requirement already satisfied: matplotlib==3.8.2 in /usr/local/lib/python3.11/dist-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (1.4.8)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.2) (1.17.0)
# Requirement already satisfied: seaborn==0.13.1 in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn==0.13.1) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn==0.13.1) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn==0.13.1) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn==0.13.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn==0.13.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.1) (1.17.0)
# Collecting pandas==2.2.1
#   Downloading pandas-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.1) (1.17.0)
# Downloading pandas-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 104.5 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.1 which is incompatible.
# Successfully installed pandas-2.2.1
# All libraries installed and imported successfully.
# NetworkX version: 3.2.1

# %% [markdown]
# # Step 2: Mount Google Drive and Load Graph Data

# %%
# Step 2: Load the Corrected Graph
import networkx as nx

# The path to our newly corrected file
corrected_path = "/content/drive/MyDrive/knowledge-graph-llms/Backup/graph_corrected.graphml"

try:
    print(f"\nAttempting to load the corrected graph from: {corrected_path}")

    # Load the graph from the corrected file
    G = nx.read_graphml(corrected_path)

    # --- Verification Step ---
    num_nodes = G.number_of_nodes()
    num_edges = G.number_of_edges()

    print("\n--- Graph Summary ---")
    print("SUCCESS! THE GRAPH IS LOADED.")
    print(f"Number of nodes: {num_nodes}")
    print(f"Number of edges: {num_edges}")
    print("---------------------")

except Exception as e:
    print(f"A final error occurred: {e}")
# Out:
# Attempting to load the corrected graph from: /content/drive/MyDrive/knowledge-graph-llms/Backup/graph_corrected.graphml
#
# --- Graph Summary ---
# SUCCESS! THE GRAPH IS LOADED.
# Number of nodes: 2424
# Number of edges: 3241
# ---------------------

# %% [markdown]
# # Step 3: Identify and List All 'Role' Nodes

# %%
# Step 3 (Corrected): Identify and List All 'Role' Nodes
import pandas as pd

# We have found the correct attribute key and the format for the value.
ATTRIBUTE_KEY_FOR_NODE_TYPE = 'labels'
ROLE_VALUE = ':Role' # The value includes a colon at the start

# Create a list of all nodes where the type is 'Role'
try:
    role_nodes = [data['id'] for node, data in G.nodes(data=True) if data.get(ATTRIBUTE_KEY_FOR_NODE_TYPE) == ROLE_VALUE]

    # Create a pandas DataFrame for clean display
    roles_df = pd.DataFrame(sorted(role_nodes), columns=['Role Title'])

    print(f"--- Analysis of 'Role' Nodes ---")
    print(f"Total number of unique roles found: {len(roles_df)}")
    print("------------------------------------")

    # Display the full list of roles in a table
    # In Colab, this will be a searchable, sortable table.
    display(roles_df)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --- Analysis of 'Role' Nodes ---
# Total number of unique roles found: 171
# ------------------------------------
#                           Role Title
# 0           Administration Assistant
# 1           Administrative Assistant
# 2     Analytics And Insights Manager
# 3                Analytics Developer
# 4            Apprentice Electricians
# ..                               ...
# 166             Vendor Administrator
# 167                Warranty Engineer
# 168  Workforce Participation Manager
# 169       Workforce Planning Analyst
# 170     Workplace Experience Manager
#
# [171 rows x 1 columns]

# %% [markdown]
# # Step 4.1: Setup, API Key, and Initial Role Extraction

# %%
# Step 4.1: Setup, API Key, and Initial Role Extraction

# --- 1. Install necessary libraries ---
# !pip install openai --quiet
# !pip install rapidfuzz --quiet
print("Required libraries are installed.")

# --- 2. Import libraries and load API Key ---
import os
import pandas as pd
from google.colab import userdata
from openai import OpenAI

try:
    # Load the API key from Colab secrets
    api_key = userdata.get('OPENAI_API_KEY')
    os.environ['OPENAI_API_KEY'] = api_key

    # Instantiate the OpenAI client. It will automatically use the API key from the environment variable.
    # Per your request, we will configure this for text-embedding-3-large later,
    # but instantiating the client now verifies the key is loaded.
    client = OpenAI()

    print("OpenAI API Key loaded and client instantiated successfully.")

except Exception as e:
    print(f"An error occurred while loading the API Key: {e}")
    print("Please ensure your secret is named 'OPENAI_API_KEY' in your Colab notebook.")

# --- 3. Extract Role Nodes from the Graph G ---
# We use the key 'labels' and value ':Role' which we discovered in our earlier inspection.
try:
    all_roles = sorted([
        data['id'] for node, data in G.nodes(data=True)
        if data.get('labels') == ':Role'
    ])

    print(f"\nSuccessfully extracted {len(all_roles)} unique roles from the graph.")

    # Display a sample of the extracted roles
    print("\n--- Sample of first 10 roles ---")
    for role in all_roles[:10]:
        print(role)
    print("--------------------------------")

except NameError:
    print("\nERROR: The graph object 'G' was not found.")
    print("Please ensure you have successfully run the graph loading steps first.")
except Exception as e:
    print(f"\nAn error occurred during role extraction: {e}")
# Out:
# Required libraries are installed.
# OpenAI API Key loaded and client instantiated successfully.
#
# Successfully extracted 171 unique roles from the graph.
#
# --- Sample of first 10 roles ---
# Administration Assistant
# Administrative Assistant
# Analytics And Insights Manager
# Analytics Developer
# Apprentice Electricians
# Area Manager
# Artificial Intelligence Manager
# Asset Engineer
# Assistant Ressources Humaines
# Automation Manager
# --------------------------------

# %% [markdown]
# #semantic matching with osca

# %%
# --- 1. Install necessary libraries ---
# !pip install openai --quiet
# !pip install pandas numpy tqdm --quiet

# --- 2. Import libraries and load API Key ---
import os
import pandas as pd
import numpy as np
from openai import OpenAI
from tqdm import tqdm
from google.colab import userdata

# Load OpenAI API key from Colab secrets
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key
client = OpenAI()

print("OpenAI API Key loaded and client instantiated successfully.")

# --- 3. Get roles ---
# (A) If you want roles from your graph 'G'
try:
    all_roles = sorted([
        data['id'] for node, data in G.nodes(data=True)
        if data.get('labels') == ':Role'
    ])
    print(f"Extracted {len(all_roles)} roles from NetworkX graph G.")
except NameError:
    # (B) Fallback: Load from a CSV as previously
    roles_path = '/content/drive/MyDrive/knowledge-graph-llms/our_roles.csv'
    all_roles = pd.read_csv(roles_path)['Our_Role'].dropna().unique().tolist()
    print(f"Extracted {len(all_roles)} roles from CSV.")

# --- 4. Load OSCA lookup file ---
osca_path = '/content/drive/MyDrive/knowledge-graph-llms/osca_titles_lookup.csv'
osca_df = pd.read_csv(osca_path)
osca_df = osca_df.dropna(subset=['Identifier', 'Description', 'Category'])

# --- 5. Principal Title Lookup ---
principal_titles = (
    osca_df[osca_df['Category'] == 'Principal Title']
    .drop_duplicates(subset=['Identifier'])
    .set_index('Identifier')['Description']
    .to_dict()
)

# --- 6. Generate Embeddings ---
def get_openai_embeddings(text_list, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=text_list,
        model=model
    )
    return [np.array(e.embedding) for e in response.data]

# Roles embeddings
batch_size = 100
role_embeddings = []
for i in tqdm(range(0, len(all_roles), batch_size), desc="Embedding your roles"):
    batch = all_roles[i:i+batch_size]
    role_embeddings.extend(get_openai_embeddings(batch))

# OSCA descriptions embeddings
osca_descriptions = osca_df['Description'].tolist()
osca_embeddings = []
for i in tqdm(range(0, len(osca_descriptions), batch_size), desc="Embedding OSCA titles"):
    batch = osca_descriptions[i:i+batch_size]
    osca_embeddings.extend(get_openai_embeddings(batch))

# --- 7. Similarity Calculation ---
from numpy.linalg import norm
def cosine_similarity(a, b):
    return np.dot(a, b) / (norm(a) * norm(b))

top_k = 3  # Top matches per role

results = []
for i, (role, role_emb) in enumerate(zip(all_roles, role_embeddings)):
    sims = [cosine_similarity(role_emb, osca_emb) for osca_emb in osca_embeddings]
    top_indices = np.argsort(sims)[::-1][:top_k]
    for rank, idx in enumerate(top_indices, 1):
        osca_row = osca_df.iloc[idx]
        principal_title = principal_titles.get(str(osca_row['Identifier']), "")
        results.append({
            'Our_Role': role,
            'OSCA_Identifier': osca_row['Identifier'],
            'OSCA_Description': osca_row['Description'],
            'OSCA_Principal_Title': principal_title,
            'Category': osca_row['Category'],
            'Similarity_Score': round(float(sims[idx]), 4),
            'Rank': rank
        })

# --- 8. Save and Preview ---
results_df = pd.DataFrame(results)
results_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_similarity_matches.csv'
results_df.to_csv(results_path, index=False)
print(f"Saved results to: {results_path}")
display(results_df.head(20))
# Out:
# OpenAI API Key loaded and client instantiated successfully.
# Extracted 171 roles from NetworkX graph G.
# Embedding your roles: 100%|██████████| 2/2 [00:01<00:00,  1.35it/s]
# Embedding OSCA titles: 100%|██████████| 34/34 [00:26<00:00,  1.26it/s]
# Saved results to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_similarity_matches.csv
#                            Our_Role  OSCA_Identifier  \
# 0          Administration Assistant           599231
# 1          Administration Assistant           522231
# 2          Administration Assistant           171231
# 3          Administrative Assistant           522231
# 4          Administrative Assistant           599231
# 5          Administrative Assistant           599231
# 6    Analytics And Insights Manager           223231
# 7    Analytics And Insights Manager           113299
# 8    Analytics And Insights Manager           221532
# 9               Analytics Developer           273333
# 10              Analytics Developer           273333
# 11              Analytics Developer           273132
# 12          Apprentice Electricians           381231
# 13          Apprentice Electricians           381231
# 14          Apprentice Electricians           381231
# 15                     Area Manager           149999
# 16                     Area Manager           161431
# 17                     Area Manager           172132
# 18  Artificial Intelligence Manager           273333
# 19  Artificial Intelligence Manager           113299
#
#                             OSCA_Description OSCA_Principal_Title  \
# 0                HR Administration Assistant
# 1                        Executive Assistant
# 2                             Office Manager
# 3                        Executive Assistant
# 4                HR Administration Assistant
# 5   Human Resources Administration Assistant
# 6                               Data Analyst
# 7          ICT Business Intelligence Manager
# 8                  Digital Marketing Analyst
# 9                      Application Developer
# 10                        Database Developer
# 11                             Web Developer
# 12                  Construction Electrician
# 13                    Commercial Electrician
# 14                       Electrical Mechanic
# 15                     Area Manager (Retail)
# 16                Operations Manager (Hotel)
# 17                           Service Manager
# 18          Artificial Intelligence Engineer
# 19                  ICT Architecture Manager
#
#                       Category  Similarity_Score  Rank
# 0            Alternative Title            0.7845     1
# 1              Principal Title            0.7699     2
# 2              Principal Title            0.7455     3
# 3              Principal Title            0.7835     1
# 4            Alternative Title            0.7796     2
# 5              Principal Title            0.7640     3
# 6              Principal Title            0.6272     1
# 7   Occupation in nec category            0.6257     2
# 8              Principal Title            0.5848     3
# 9               Specialisation            0.7764     1
# 10              Specialisation            0.7233     2
# 11             Principal Title            0.7041     3
# 12              Specialisation            0.6823     1
# 13              Specialisation            0.6624     2
# 14           Alternative Title            0.6565     3
# 15  Occupation in nec category            0.8695     1
# 16              Specialisation            0.6847     2
# 17           Alternative Title            0.6763     3
# 18              Specialisation            0.7860     1
# 19  Occupation in nec category            0.6127     2

# %% [markdown]
# # Split Matches Into Categories and Save to Files

# %%
# Assume results_df is already created as above

# Category 1: Auto-match (exact semantic match)
matched_df = results_df[results_df['Similarity_Score'] == 1.0].copy()
matched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_semantic_matched.csv'
matched_df.to_csv(matched_path, index=False)
print(f"Auto-matched (Similarity=1.0) saved to: {matched_path}")

# Category 2: LLM Review (similarity between 0.8 and 1, exclusive)
llm_review_df = results_df[(results_df['Similarity_Score'] < 1.0) & (results_df['Similarity_Score'] >= 0.8)].copy()
llm_review_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_llm_review.csv'
llm_review_df.to_csv(llm_review_path, index=False)
print(f"LLM review candidates (0.8 ≤ Similarity < 1.0) saved to: {llm_review_path}")

# Category 3: Unmatched (similarity below 0.8)
unmatched_df = results_df[results_df['Similarity_Score'] < 0.8].copy()
unmatched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_unmatched.csv'
unmatched_df.to_csv(unmatched_path, index=False)
print(f"Unmatched roles (Similarity < 0.8) saved to: {unmatched_path}")
# Out:
# Auto-matched (Similarity=1.0) saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_semantic_matched.csv
# LLM review candidates (0.8 ≤ Similarity < 1.0) saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_llm_review.csv
# Unmatched roles (Similarity < 0.8) saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_unmatched.csv

# %% [markdown]
# #LLM Review: One-by-One, With Context from Auto-Matches

# %%
# --- LLM Review: Prefer Matching to Existing Auto-Matched OSCA Titles, Otherwise Use Semantic Candidate ---

# !pip install openai --quiet

import pandas as pd
import os
import time
from openai import OpenAI
from google.colab import userdata

# Load OpenAI API Key from Colab secrets
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key
client = OpenAI()

# Load data files
cat1_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_semantic_matched.csv'
llm_review_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_llm_review.csv'

cat1_df = pd.read_csv(cat1_path)
llm_review_df = pd.read_csv(llm_review_path)

# Prepare the list of auto-matched OSCA titles (for the prompt)
auto_matched_list = cat1_df[['OSCA_Description', 'OSCA_Principal_Title']].drop_duplicates().to_dict(orient='records')

# Filter out roles already in category 1 (should not LLM-review those)
auto_matched_roles = set(cat1_df['Our_Role'])
llm_review_df_filtered = llm_review_df[~llm_review_df['Our_Role'].isin(auto_matched_roles)].copy()

# LLM prompt function
def build_llm_prompt(role, candidate, auto_matched_list):
    prompt = (
        "You are an expert in classifying construction workforce roles. "
        "Your first priority is to match the project role to any OSCA title already matched (listed below) if the technical skills and daily responsibilities align—ignore differences in seniority, managerial, or assistant level. "
        "If there is no suitable match among the auto-matched OSCA titles, then assess the semantic similarity candidate OSCA title as a possible match. "
        "Approve a match if the technical skills and job tasks align.\n\n"
        f"Project Role: {role}\n"
        "Auto-matched OSCA Titles:\n"
    )
    for entry in auto_matched_list:
        prompt += f"- {entry['OSCA_Description']} (Principal: {entry['OSCA_Principal_Title']})\n"
    prompt += (
        "\nSemantic Similarity Candidate OSCA Title:\n"
        f"- {candidate['OSCA_Description']} (Principal: {candidate['OSCA_Principal_Title']})\n"
        f"Category: {candidate['Category']}\n"
        f"Similarity Score: {candidate['Similarity_Score']}\n\n"
        "Instructions:\n"
        "1. If the project role matches the technical skills of any auto-matched OSCA title, reply: 'Match: [OSCA title]' and a one-sentence justification.\n"
        "2. If not, consider the semantic similarity candidate OSCA title. If that aligns, reply: 'Match: [Candidate OSCA title]' and a one-sentence justification.\n"
        "3. If neither is a match, reply: 'No suitable match' and a brief justification."
    )
    return prompt

# LLM review loop, one by one
llm_results = []

for idx, row in llm_review_df_filtered.iterrows():
    role = row['Our_Role']
    user_prompt = build_llm_prompt(role, row, auto_matched_list)
    try:
        response = client.chat.completions.create(
            model="o3-mini",
            messages=[
                {"role": "system", "content": "You are an expert in Australian construction workforce roles."},
                {"role": "user", "content": user_prompt}
            ]
        )
        reply = response.choices[0].message.content.strip()
    except Exception as e:
        reply = f"Error: {e}"
    llm_results.append({
        "Our_Role": role,
        "OSCA_Identifier": row['OSCA_Identifier'],
        "OSCA_Description": row['OSCA_Description'],
        "OSCA_Principal_Title": row['OSCA_Principal_Title'],
        "Category": row['Category'],
        "Similarity_Score": row['Similarity_Score'],
        "LLM_Decision": reply
    })
    print(f"Reviewed: {role} | LLM: {reply}")
    time.sleep(1.2)  # Respect OpenAI API rate limits

# Save results
llm_results_df = pd.DataFrame(llm_results)
llm_results_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_llm_reviewed.csv'
llm_results_df.to_csv(llm_results_path, index=False)
print(f"\nLLM-reviewed results saved to: {llm_results_path}")

# Preview
display(llm_results_df.head(10))
# Out:
# Reviewed: Area Manager | LLM: Match: Area Manager (Retail) – The project role’s oversight and management responsibilities align well with those in the candidate title despite the slight industry variation.
# Reviewed: Catering Coordinator | LLM: Match: Catering Manager – The role of a Catering Coordinator aligns closely with that of a Catering Manager, as both involve managing catering operations, logistics, and service delivery.
# Reviewed: Catering Coordinator | LLM: Match: Catering Assistant – The role involves coordinating catering services, and despite the title difference in seniority, the technical skills and daily responsibilities align closely with those of a catering assistant.
# Reviewed: Cloud Infrastructure Engineer | LLM: Match: Cloud Infrastructure Architect – This candidate title aligns closely with the technical skills and daily responsibilities required for designing and managing cloud-based systems inherent in a Cloud Infrastructure Engineer role.
# Reviewed: Cloud Infrastructure Engineer | LLM: Match: Cloud Engineer – The role of a Cloud Infrastructure Engineer aligns well with the technical skills and daily responsibilities of a Cloud Engineer.
# Reviewed: Contracts Administrator | LLM: Match: Contract Administrator — The candidate OSCA title aligns closely with the role's technical skills and daily tasks involving contract management and administration.
# Reviewed: Control Systems Engineer | LLM: Match: Control Systems Engineer (Production or Plant) – The project role’s focus on designing and managing control systems directly aligns with the technical skills and job tasks of the candidate OSCA title.
# Reviewed: Data Engineering Manager | LLM: Match: Data Engineer. The technical expertise and daily responsibilities of managing and executing data engineering tasks align with those of a Data Engineer, regardless of the managerial aspect.
# Reviewed: Data Engineers | LLM: Match: Data Engineer
# The project role "Data Engineers" directly aligns with the technical skills and daily tasks described in the auto-matched OSCA title "Data Engineer."
# Reviewed: Data Support Analyst | LLM: Match: Data Analyst
# The role of a Data Support Analyst aligns with the responsibilities of a Data Analyst, as both focus on managing, interpreting, and supporting data tasks, which meets the technical skills criteria.
# Reviewed: Devops Engineer | LLM: Match: DevOps Engineer – This title aligns precisely with the technical skills and daily responsibilities of the project role, making it the most suitable match.
# Reviewed: Electrical Controls Engineer | LLM: Match: Electrical Engineer
# The technical skills and daily responsibilities of an Electrical Controls Engineer align well with those expected of an Electrical Engineer, particularly in designing and implementing control systems in electrical projects.
# Reviewed: Electrical Controls Engineer | LLM: Match: Electrical Engineer
# The role of an Electrical Controls Engineer aligns well with the technical skills and daily responsibilities typically handled by an Electrical Engineer, making it an appropriate match.
# Reviewed: Electrical Project Engineer | LLM: Match: Electrical Engineer – The role of an Electrical Project Engineer aligns closely with the technical skills and responsibilities of an Electrical Engineer, focusing on electrical system design and project management.
# Reviewed: Electrical Project Engineer | LLM: Match: Electrical Engineer. The role's design, technical oversight, and engineering responsibilities closely align with those of an Electrical Engineer.
# Reviewed: Electrical Technician | LLM: Match: Electrical Engineering Technician – The role's technical skills and daily responsibilities align closely with maintaining and supporting electrical systems as outlined in this OSCA title.
# Reviewed: Electrical Technician | LLM: Match: Electrical Engineering Technician – The role requires electrical technical skills and responsibilities that directly align with those of an Electrical Engineering Technician.
# Reviewed: Electrical Technician | LLM: Match: Electrical Engineering Technician
# The tasks and technical skills of an Electrical Technician align closely with those expected in an Electrical Engineering Technician role.
# Reviewed: Electrician | LLM: Match: Industrial Electrician
# The project role of Electrician aligns closely with the technical skills and daily responsibilities of an Industrial Electrician in the auto-matched OSCA titles.
# Reviewed: Electrician | LLM: Match: Industrial Electrician – The project role of Electrician closely aligns with the technical skills and daily tasks of an Industrial Electrician as reflected in the auto-matched OSCA titles.
# Reviewed: Electrician Technician | LLM: Match: Electrical Engineering Technician – The technical skills and daily tasks of an Electrician Technician closely align with those of an Electrical Engineering Technician.
# Reviewed: Field Electrician | LLM: Match: Electrical Fitter
#
# The Field Electrician role aligns closely with the technical skills and daily responsibilities of an Electrical Fitter, as both involve installing, maintaining, and troubleshooting electrical systems on-site.
# Reviewed: Field Electrician | LLM: Match: Industrial Electrician – The Field Electrician role aligns with the hands-on, field-based electrical work typical of an Industrial Electrician.
# Reviewed: Finance Administrative Assistant | LLM: Match: Financial Administrator – The role’s focus on providing finance administrative support aligns more closely with the responsibilities and technical skills of a Financial Administrator than with any of the auto-matched titles.
# Reviewed: Finance Administrator | LLM: Match: Financial Administrator.
#
# The Finance Administrator role aligns closely with the responsibilities and technical skills of the Financial Administrator OSCA title, making it the most appropriate match.
# Reviewed: Finance Administrator | LLM: Match: Finance Manager
#
# The Finance Manager candidate aligns closely with the technical skills and daily financial administrative tasks of the Finance Administrator role, making it the most appropriate match despite the difference in phrasing.
# Reviewed: Finance Administrator | LLM: Match: Payroll Officer
#
# The Finance Administrator role involves managing financial transactions, including payroll processing and record keeping, which aligns with the technical skills and daily responsibilities of a Payroll Officer.
# Reviewed: Finance Analyst | LLM: Match: Financial Analyst – The technical skills and job tasks of a Finance Analyst closely align with the candidate OSCA title "Financial Analyst," making it the best match.
# Reviewed: Human Resources Analyst | LLM: Match: Workforce Planning Analyst
#
# The Human Resources Analyst role involves analyzing and planning workforce data, which aligns closely with the technical skills and daily responsibilities of a Workforce Planning Analyst.
# Reviewed: It Service Delivery Manager | LLM: Match: Service Manager
# The technical skills and daily responsibilities of an IT Service Delivery Manager, such as overseeing service delivery functions, align closely with those of a Service Manager.
# Reviewed: It Systems Manager | LLM: Match: ICT Systems Manager – The role aligns well with IT systems management tasks and technical skills as demonstrated by the candidate title's responsibilities.
# Reviewed: Mechanical Fitter | LLM: Match: Maintenance Fitter – The technical skills and daily tasks of a Mechanical Fitter align closely with those of a Maintenance Fitter, making it an appropriate match.
# Reviewed: Mechanical Fitter | LLM: No suitable match – the available OSCA titles focus on electrical or data-related technical skills, which do not align with the mechanical fitting skills and daily responsibilities required by a Mechanical Fitter.
# Reviewed: Mechanical Project Engineer | LLM: Match: Mechanical Engineer – The technical skills and daily tasks of a Mechanical Engineer closely align with those of a Mechanical Project Engineer.
# Reviewed: Mechanical Service Technician | LLM: Match: Mechanical Engineering Technician
# The role of a Mechanical Service Technician aligns closely with the technical skills and daily tasks of a Mechanical Engineering Technician, making it the most suitable match despite the difference in job title wording.
# Reviewed: Mechanical/Electrical Engineer | LLM: Match: Mechanical Engineer
#
# The combined mechanical/electrical role’s technical skills and daily tasks more closely align with the Mechanical Engineer candidate—covering the core engineering design and system integration aspects—even though it involves electrical elements that are common in current mechanical engineering practice.
# Reviewed: Mechanical/Electrical Engineer | LLM: Match: Electrical Engineer
# The project role's electrical engineering aspects align directly with the technical skills and daily responsibilities of the Electrical Engineer OSCA title.
# Reviewed: Mechanical/Electrical Engineer | LLM: Match: Electrical Engineer
# The project's electrical engineering responsibilities align directly with the technical skills and daily tasks of this auto-matched title.
# Reviewed: Motion Graphics Designer | LLM: Match: Motion Designer – The technical skills and daily responsibilities of a Motion Graphics Designer directly align with those of a Motion Designer.
# Reviewed: Operations Manager | LLM: Match: Operations Manager (Production) – The project role's operations management responsibilities and technical skills closely align with those of the candidate OSCA title, making it a suitable match.
# Reviewed: Operations Manager | LLM: Match: Operations Manager (Hotel) – Although the industry differs, the technical responsibilities and day-to-day operations align closely with those of a general operations manager.
# Reviewed: Procurement Administrator | LLM: Match: Procurement Officer – The role of Procurement Administrator closely aligns with the responsibilities and technical skills of a Procurement Officer, making it an appropriate match.
# Reviewed: Procurement Administrator | LLM: Match: Procurement Manager
# The Procurement Manager title aligns with the core procurement processes and administrative tasks involved in the role, making it the best fit despite differences in seniority.
# Reviewed: Project Administrator | LLM: Match: Program or Project Administrator – The candidate OSCA title aligns closely with the technical skills and day-to-day responsibilities typically associated with a Project Administrator.
# Reviewed: Project Administrator | LLM: Match: Project Coordinator
# The Project Administrator’s responsibilities in managing and coordinating project tasks align well with the responsibilities of a Project Coordinator.
# Reviewed: Project Controls Coordinator | LLM: Match: Project Coordinator – The role's responsibilities in coordinating project controls align closely with the tasks of a Project Coordinator, making it a suitable match.
# Reviewed: Project Manager | LLM: Match: Project Coordinator – The role aligns well with the project manager's responsibilities in coordinating project tasks, schedules, and resource management, despite differences in seniority.
# Reviewed: Project Manager | LLM: Match: Construction Project Manager
# The candidate title directly matches the Project Manager role by encompassing the key project management responsibilities and technical skills required in construction.
# Reviewed: Sales And Marketing Manager | LLM: Match: Sales and Marketing Manager
# The candidate OSCA title directly corresponds to the project role in terms of technical expertise and daily responsibilities.
# Reviewed: Solution Engineer | LLM: Match: Application Engineer – The role of a Solution Engineer, which involves designing and implementing integrated technological solutions, aligns closely with the responsibilities and skillset of an Application Engineer.
# Reviewed: Sustainability Manager | LLM: Match: Environment and Sustainability Manager – This title directly encompasses the sustainability management responsibilities and aligns accurately with the technical skills and daily tasks of a Sustainability Manager.
#
# LLM-reviewed results saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_llm_reviewed.csv
#                         Our_Role  OSCA_Identifier  \
# 0                   Area Manager           149999
# 1           Catering Coordinator           161232
# 2           Catering Coordinator           851231
# 3  Cloud Infrastructure Engineer           273231
# 4  Cloud Infrastructure Engineer           273331
# 5        Contracts Administrator           511131
# 6       Control Systems Engineer           243533
# 7       Data Engineering Manager           223233
# 8                 Data Engineers           223233
# 9           Data Support Analyst           223231
#
#                                  OSCA_Description  OSCA_Principal_Title  \
# 0                           Area Manager (Retail)                   NaN
# 1                                Catering Manager                   NaN
# 2                              Catering Assistant                   NaN
# 3                  Cloud Infrastructure Architect                   NaN
# 4                                  Cloud Engineer                   NaN
# 5                          Contract Administrator                   NaN
# 6  Control Systems Engineer (Production or Plant)                   NaN
# 7                                   Data Engineer                   NaN
# 8                                   Data Engineer                   NaN
# 9                                    Data Analyst                   NaN
#
#                      Category  Similarity_Score  \
# 0  Occupation in nec category            0.8695
# 1             Principal Title            0.8629
# 2              Specialisation            0.8011
# 3           Alternative Title            0.9213
# 4             Principal Title            0.8543
# 5             Principal Title            0.9274
# 6              Specialisation            0.8139
# 7             Principal Title            0.8403
# 8             Principal Title            0.8949
# 9             Principal Title            0.8091
#
#                                         LLM_Decision
# 0  Match: Area Manager (Retail) – The project rol...
# 1  Match: Catering Manager – The role of a Cateri...
# 2  Match: Catering Assistant – The role involves ...
# 3  Match: Cloud Infrastructure Architect – This c...
# 4  Match: Cloud Engineer – The role of a Cloud In...
# 5  Match: Contract Administrator — The candidate ...
# 6  Match: Control Systems Engineer (Production or...
# 7  Match: Data Engineer. The technical expertise ...
# 8  Match: Data Engineer  \nThe project role "Data...
# 9  Match: Data Analyst  \nThe role of a Data Supp...

# %%
import pandas as pd

# Load previous outputs
auto_matched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_semantic_matched.csv'
llm_reviewed_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_llm_reviewed.csv'
semantic_unmatched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/osca_semantic_unmatched.csv'

auto_matched_df = pd.read_csv(auto_matched_path)
llm_reviewed_df = pd.read_csv(llm_reviewed_path)
semantic_unmatched_df = pd.read_csv(semantic_unmatched_path)

# 1. All matches (for graph update)
llm_matched_df = llm_reviewed_df[llm_reviewed_df['LLM_Decision'].str.lower().str.startswith('match')].copy()
all_matched_df = pd.concat([auto_matched_df, llm_matched_df], ignore_index=True)

all_matched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_all_matched.csv'
all_matched_df.to_csv(all_matched_path, index=False)
print(f"All matched (semantic + LLM) saved to: {all_matched_path}")

# 2. Final unmatched
llm_unmatched_df = llm_reviewed_df[llm_reviewed_df['LLM_Decision'].str.lower().str.startswith('no suitable match')].copy()
final_unmatched_df = pd.concat([semantic_unmatched_df, llm_unmatched_df], ignore_index=True)

final_unmatched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/final_unmatched_roles.csv'
final_unmatched_df.to_csv(final_unmatched_path, index=False)
print(f"Final unmatched roles saved to: {final_unmatched_path}")

# Preview outputs
print("\n--- Preview: All matched roles ---")
display(all_matched_df.head(10))
print("\n--- Preview: Final unmatched roles ---")
display(final_unmatched_df.head(10))
# Out:
# All matched (semantic + LLM) saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_all_matched.csv
# Final unmatched roles saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/final_unmatched_roles.csv
#
# --- Preview: All matched roles ---
#                             Our_Role  OSCA_Identifier  \
# 0              Automation Technician           313999
# 1          Communications Technician           382334
# 2                     Data Architect           223232
# 3                      Data Engineer           223233
# 4                     Data Scientist           223234
# 5          Digital Marketing Analyst           221532
# 6                Electrical Engineer           243331
# 7  Electrical Engineering Technician           313232
# 8                  Electrical Fitter           381232
# 9              Environmental Officer           244332
#
#                     OSCA_Description  OSCA_Principal_Title  \
# 0              Automation Technician                   NaN
# 1          Communications Technician                   NaN
# 2                     Data Architect                   NaN
# 3                      Data Engineer                   NaN
# 4                     Data Scientist                   NaN
# 5          Digital Marketing Analyst                   NaN
# 6                Electrical Engineer                   NaN
# 7  Electrical Engineering Technician                   NaN
# 8                  Electrical Fitter                   NaN
# 9              Environmental Officer                   NaN
#
#                      Category  Similarity_Score  Rank LLM_Decision
# 0  Occupation in nec category               1.0   1.0          NaN
# 1           Alternative Title               1.0   1.0          NaN
# 2             Principal Title               1.0   1.0          NaN
# 3             Principal Title               1.0   1.0          NaN
# 4             Principal Title               1.0   1.0          NaN
# 5             Principal Title               1.0   1.0          NaN
# 6             Principal Title               1.0   1.0          NaN
# 7             Principal Title               1.0   1.0          NaN
# 8             Principal Title               1.0   1.0          NaN
# 9           Alternative Title               1.0   1.0          NaN
# --- Preview: Final unmatched roles ---
#                          Our_Role  OSCA_Identifier  \
# 0        Administration Assistant           599231
# 1        Administration Assistant           522231
# 2        Administration Assistant           171231
# 3        Administrative Assistant           522231
# 4        Administrative Assistant           599231
# 5        Administrative Assistant           599231
# 6  Analytics And Insights Manager           223231
# 7  Analytics And Insights Manager           113299
# 8  Analytics And Insights Manager           221532
# 9             Analytics Developer           273333
#
#                            OSCA_Description  OSCA_Principal_Title  \
# 0               HR Administration Assistant                   NaN
# 1                       Executive Assistant                   NaN
# 2                            Office Manager                   NaN
# 3                       Executive Assistant                   NaN
# 4               HR Administration Assistant                   NaN
# 5  Human Resources Administration Assistant                   NaN
# 6                              Data Analyst                   NaN
# 7         ICT Business Intelligence Manager                   NaN
# 8                 Digital Marketing Analyst                   NaN
# 9                     Application Developer                   NaN
#
#                      Category  Similarity_Score  Rank LLM_Decision
# 0           Alternative Title            0.7845   1.0          NaN
# 1             Principal Title            0.7699   2.0          NaN
# 2             Principal Title            0.7455   3.0          NaN
# 3             Principal Title            0.7835   1.0          NaN
# 4           Alternative Title            0.7796   2.0          NaN
# 5             Principal Title            0.7640   3.0          NaN
# 6             Principal Title            0.6272   1.0          NaN
# 7  Occupation in nec category            0.6257   2.0          NaN
# 8             Principal Title            0.5848   3.0          NaN
# 9              Specialisation            0.7764   1.0          NaN

# %%
import pandas as pd

# Load your matched file
matched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_all_matched.csv'
df = pd.read_csv(matched_path)

def select_best_per_role(subdf):
    principals = subdf[subdf['Category'].str.lower() == 'principal title']
    if not principals.empty:
        # Pick the Principal Title with highest similarity
        return principals.loc[principals['Similarity_Score'].idxmax()]
    else:
        # No principal: pick the highest similarity among others
        return subdf.loc[subdf['Similarity_Score'].idxmax()]

best_df = df.groupby('Our_Role', group_keys=False).apply(select_best_per_role).reset_index(drop=True)

# Save output
output_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_one_to_one_matched.csv'
best_df.to_csv(output_path, index=False)
print(f"Strict 1-to-1 matched (principal-priority) roles saved to: {output_path}")

# Preview
display(best_df.head(20))
# Out:
# Strict 1-to-1 matched (principal-priority) roles saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_one_to_one_matched.csv
# /tmp/ipython-input-28-849336326.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_df = df.groupby('Our_Role', group_keys=False).apply(select_best_per_role).reset_index(drop=True)
#                              Our_Role  OSCA_Identifier  \
# 0                        Area Manager           149999
# 1               Automation Technician           313999
# 2                Catering Coordinator           161232
# 3       Cloud Infrastructure Engineer           273331
# 4           Communications Technician           382334
# 5             Contracts Administrator           511131
# 6            Control Systems Engineer           243533
# 7                      Data Architect           223232
# 8                       Data Engineer           223233
# 9            Data Engineering Manager           223233
# 10                     Data Engineers           223233
# 11                     Data Scientist           223234
# 12               Data Support Analyst           223231
# 13                    Devops Engineer           273332
# 14          Digital Marketing Analyst           221532
# 15       Electrical Controls Engineer           243331
# 16                Electrical Engineer           243331
# 17  Electrical Engineering Technician           313232
# 18                  Electrical Fitter           381232
# 19        Electrical Project Engineer           243331
#
#                                   OSCA_Description  OSCA_Principal_Title  \
# 0                            Area Manager (Retail)                   NaN
# 1                            Automation Technician                   NaN
# 2                                 Catering Manager                   NaN
# 3                                   Cloud Engineer                   NaN
# 4                        Communications Technician                   NaN
# 5                           Contract Administrator                   NaN
# 6   Control Systems Engineer (Production or Plant)                   NaN
# 7                                   Data Architect                   NaN
# 8                                    Data Engineer                   NaN
# 9                                    Data Engineer                   NaN
# 10                                   Data Engineer                   NaN
# 11                                  Data Scientist                   NaN
# 12                                    Data Analyst                   NaN
# 13                                 DevOps Engineer                   NaN
# 14                       Digital Marketing Analyst                   NaN
# 15                             Electrical Engineer                   NaN
# 16                             Electrical Engineer                   NaN
# 17               Electrical Engineering Technician                   NaN
# 18                               Electrical Fitter                   NaN
# 19                             Electrical Engineer                   NaN
#
#                       Category  Similarity_Score  Rank  \
# 0   Occupation in nec category            0.8695   NaN
# 1   Occupation in nec category            1.0000   1.0
# 2              Principal Title            0.8629   NaN
# 3              Principal Title            0.8543   NaN
# 4            Alternative Title            1.0000   1.0
# 5              Principal Title            0.9274   NaN
# 6               Specialisation            0.8139   NaN
# 7              Principal Title            1.0000   1.0
# 8              Principal Title            1.0000   1.0
# 9              Principal Title            0.8403   NaN
# 10             Principal Title            0.8949   NaN
# 11             Principal Title            1.0000   1.0
# 12             Principal Title            0.8091   NaN
# 13             Principal Title            0.9428   NaN
# 14             Principal Title            1.0000   1.0
# 15             Principal Title            0.8303   NaN
# 16             Principal Title            1.0000   1.0
# 17             Principal Title            1.0000   1.0
# 18             Principal Title            1.0000   1.0
# 19             Principal Title            0.8936   NaN
#
#                                          LLM_Decision
# 0   Match: Area Manager (Retail) – The project rol...
# 1                                                 NaN
# 2   Match: Catering Manager – The role of a Cateri...
# 3   Match: Cloud Engineer – The role of a Cloud In...
# 4                                                 NaN
# 5   Match: Contract Administrator — The candidate ...
# 6   Match: Control Systems Engineer (Production or...
# 7                                                 NaN
# 8                                                 NaN
# 9   Match: Data Engineer. The technical expertise ...
# 10  Match: Data Engineer  \nThe project role "Data...
# 11                                                NaN
# 12  Match: Data Analyst  \nThe role of a Data Supp...
# 13  Match: DevOps Engineer – This title aligns pre...
# 14                                                NaN
# 15  Match: Electrical Engineer  \nThe technical sk...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Match: Electrical Engineer. The role's design,...

# %%
# --- 1. Install only pandas (if not present) ---
# !pip install pandas --quiet

import pandas as pd

# --- 2. Extract roles from the graph G ---
try:
    all_roles = sorted([
        data['id'] for node, data in G.nodes(data=True)
        if data.get('labels') == ':Role'
    ])
    print(f"\nSuccessfully extracted {len(all_roles)} unique roles from the graph.")
    print("--- Sample of first 10 roles ---")
    for role in all_roles[:10]:
        print(role)
    print("--------------------------------")
except NameError:
    print("\nERROR: The graph object 'G' was not found.")
    all_roles = []
except Exception as e:
    print(f"\nAn error occurred during role extraction: {e}")
    all_roles = []

# --- 3. Compare with matched roles and report ---
matched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_one_to_one_matched.csv'
matched_df = pd.read_csv(matched_path)

all_roles_set = set(all_roles)
matched_roles_set = set(matched_df['Our_Role'].dropna().unique())
unmatched_roles = sorted(all_roles_set - matched_roles_set)

# Reporting
total_roles = len(all_roles_set)
matched_count = len(matched_roles_set & all_roles_set)
unmatched_count = len(unmatched_roles)
matched_percent = matched_count / total_roles * 100 if total_roles else 0
unmatched_percent = unmatched_count / total_roles * 100 if total_roles else 0

print(f"\n=== Matching Summary ===")
print(f"Total roles extracted from graph: {total_roles}")
print(f"Roles with OSCA match:           {matched_count} ({matched_percent:.1f}%)")
print(f"Roles without a match:           {unmatched_count} ({unmatched_percent:.1f}%)")

# --- 4. Save unmatched roles for further processing ---
unmatched_roles_df = pd.DataFrame({'Our_Role': unmatched_roles})
unmatched_save_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_for_review.csv'
unmatched_roles_df.to_csv(unmatched_save_path, index=False)
print(f"Unmatched roles saved to: {unmatched_save_path}")

# Preview
display(unmatched_roles_df.head(10))
# Out:
# Successfully extracted 171 unique roles from the graph.
# --- Sample of first 10 roles ---
# Administration Assistant
# Administrative Assistant
# Analytics And Insights Manager
# Analytics Developer
# Apprentice Electricians
# Area Manager
# Artificial Intelligence Manager
# Asset Engineer
# Assistant Ressources Humaines
# Automation Manager
# --------------------------------
#
# === Matching Summary ===
# Total roles extracted from graph: 171
# Roles with OSCA match:           53 (31.0%)
# Roles without a match:           118 (69.0%)
# Unmatched roles saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_for_review.csv
#                           Our_Role
# 0         Administration Assistant
# 1         Administrative Assistant
# 2   Analytics And Insights Manager
# 3              Analytics Developer
# 4          Apprentice Electricians
# 5  Artificial Intelligence Manager
# 6                   Asset Engineer
# 7    Assistant Ressources Humaines
# 8               Automation Manager
# 9             Automation Paralegal

# %%
# Import networkx if not already imported
import networkx as nx

# Basic graph statistics
print(f"Total nodes in graph:        {G.number_of_nodes()}")
print(f"Total relationships (edges): {G.number_of_edges()}")

# Node type counts (by 'labels')
from collections import Counter

node_labels = [data.get('labels', 'UNKNOWN') for _, data in G.nodes(data=True)]
label_counts = Counter(node_labels)
print("\nNode counts by type (labels):")
for label, count in label_counts.items():
    print(f"  {label}: {count}")

# Edge type counts (by 'type', if present)
if G.number_of_edges() > 0:
    edge_types = [data.get('type', 'UNKNOWN') for _, _, data in G.edges(data=True)]
    edge_type_counts = Counter(edge_types)
    print("\nRelationship counts by type (edge 'type'):")
    for etype, count in edge_type_counts.items():
        print(f"  {etype}: {count}")
else:
    print("\nNo relationships (edges) present in graph.")

# Optional: show a few sample nodes and edges
print("\n--- Sample nodes ---")
for n, d in list(G.nodes(data=True))[:5]:
    print(f"{n}: {d}")
print("\n--- Sample edges ---")
for s, t, d in list(G.edges(data=True))[:5]:
    print(f"{s} -> {t}: {d}")
# Out:
# Total nodes in graph:        2424
# Total relationships (edges): 3241
#
# Node counts by type (labels):
#   :Role: 171
#   :Technical skill: 912
#   :Soft skill: 198
#   :Task: 824
#   :Tool: 317
#   :Skill: 2
#
# Relationship counts by type (edge 'type'):
#   UNKNOWN: 3241
#
# --- Sample nodes ---
# n0: {'labels': ':Role', 'id': 'Analytics And Insights Manager'}
# n1: {'labels': ':Technical skill', 'id': 'Predictive Analytics'}
# n2: {'labels': ':Technical skill', 'id': 'Machine Learning'}
# n3: {'labels': ':Soft skill', 'id': 'Communication'}
# n4: {'labels': ':Soft skill', 'id': 'Project Management'}
#
# --- Sample edges ---
# n0 -> n1: {'label': 'REQUIRES_SKILL'}
# n0 -> n2: {'label': 'REQUIRES_SKILL'}
# n0 -> n3: {'label': 'REQUIRES_SKILL'}
# n0 -> n4: {'label': 'REQUIRES_SKILL'}
# n0 -> n12: {'label': 'USES_TOOL'}

# %% [markdown]
# # Step 0: Create a Graph Backup Before Any Change

# %%
import networkx as nx
import os

backup_dir = '/content/drive/MyDrive/knowledge-graph-llms/graph_backups'
os.makedirs(backup_dir, exist_ok=True)
backup_path = os.path.join(backup_dir, 'G_before_osca_update.graphml')
nx.write_graphml(G, backup_path)
print(f"Backup saved to: {backup_path}")
# Out:
# Backup saved to: /content/drive/MyDrive/knowledge-graph-llms/graph_backups/G_before_osca_update.graphml

# %% [markdown]
# #Step 1: Prepare Lookup Index for Role Nodes (Performance Improvement)

# %%
# Build fast lookup: role name -> node key
role_name_to_node_key = {
    d.get('id'): n
    for n, d in G.nodes(data=True)
    if d.get('labels') == ':Role' and d.get('id') is not None
}
print(f"Role node index created. Unique roles in graph: {len(role_name_to_node_key)}")
# Out:
# Role node index created. Unique roles in graph: 171

# %% [markdown]
# #Step 2: Add/Update OSCAOccupation Nodes and Enriched Relationships

# %%
import pandas as pd

osca_csv = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_one_to_one_matched.csv'
osca_df = pd.read_csv(osca_csv)

added_osca_nodes = 0
added_edges = 0
skipped_roles = 0

for _, row in osca_df.iterrows():
    osca_id = str(row['OSCA_Identifier'])
    osca_node_key = f"osca_{osca_id}"
    # Create or update OSCAOccupation node
    if not G.has_node(osca_node_key):
        G.add_node(
            osca_node_key,
            labels=':OSCAOccupation',
            osca_id=osca_id,
            description=row['OSCA_Description'],
            principal_title=row.get('OSCA_Principal_Title', ''),
            category=row.get('Category', '')
        )
        added_osca_nodes += 1

    # Fast lookup for Role node
    our_role_name = row['Our_Role']
    our_role_node = role_name_to_node_key.get(our_role_name)
    if not our_role_node:
        print(f"[Warning] Role node '{our_role_name}' not found in graph. Skipping.")
        skipped_roles += 1
        continue

    # Add enriched edge (with match metadata)
    G.add_edge(
        our_role_node,
        osca_node_key,
        label='MATCHED_TO_OSCA',
        similarity_score=row.get('Similarity_Score', ''),
        llm_decision=row.get('LLM_Decision', ''),
        rank=row.get('Rank', '')
    )
    added_edges += 1

print(f"\nAdded {added_osca_nodes} OSCAOccupation nodes (if not already present).")
print(f"Created {added_edges} MATCHED_TO_OSCA relationships.")
if skipped_roles:
    print(f"Skipped {skipped_roles} unmatched roles (not present in graph).")
# Out:
# Added 43 OSCAOccupation nodes (if not already present).
# Created 53 MATCHED_TO_OSCA relationships.

# %%
# List all OSCAOccupation nodes with key properties
osca_nodes = [
    (n, d.get('osca_id'), d.get('description'), d.get('principal_title'), d.get('category'))
    for n, d in G.nodes(data=True)
    if d.get('labels') == ':OSCAOccupation'
]

osca_nodes_df = pd.DataFrame(
    osca_nodes,
    columns=['Node Key', 'OSCA_Identifier', 'OSCA_Description', 'OSCA_Principal_Title', 'Category']
)

print(f"Total OSCAOccupation nodes in graph: {len(osca_nodes_df)}")
display(osca_nodes_df.head(20))
# Out:
# Total OSCAOccupation nodes in graph: 43
#        Node Key OSCA_Identifier  \
# 0   osca_149999          149999
# 1   osca_313999          313999
# 2   osca_161232          161232
# 3   osca_273331          273331
# 4   osca_382334          382334
# 5   osca_511131          511131
# 6   osca_243533          243533
# 7   osca_223232          223232
# 8   osca_223233          223233
# 9   osca_223234          223234
# 10  osca_223231          223231
# 11  osca_273332          273332
# 12  osca_221532          221532
# 13  osca_243331          243331
# 14  osca_313232          313232
# 15  osca_381232          381232
# 16  osca_381231          381231
# 17  osca_244332          244332
# 18  osca_244432          244432
# 19  osca_111231          111231
#
#                                   OSCA_Description  OSCA_Principal_Title  \
# 0                            Area Manager (Retail)                   NaN
# 1                            Automation Technician                   NaN
# 2                                 Catering Manager                   NaN
# 3                                   Cloud Engineer                   NaN
# 4                        Communications Technician                   NaN
# 5                           Contract Administrator                   NaN
# 6   Control Systems Engineer (Production or Plant)                   NaN
# 7                                   Data Architect                   NaN
# 8                                    Data Engineer                   NaN
# 9                                   Data Scientist                   NaN
# 10                                    Data Analyst                   NaN
# 11                                 DevOps Engineer                   NaN
# 12                       Digital Marketing Analyst                   NaN
# 13                             Electrical Engineer                   NaN
# 14               Electrical Engineering Technician                   NaN
# 15                               Electrical Fitter                   NaN
# 16                           Electrician (General)                   NaN
# 17                           Environmental Officer                   NaN
# 18                         Environmental Scientist                   NaN
# 19                         Financial Administrator                   NaN
#
#                       Category
# 0   Occupation in nec category
# 1   Occupation in nec category
# 2              Principal Title
# 3              Principal Title
# 4            Alternative Title
# 5              Principal Title
# 6               Specialisation
# 7              Principal Title
# 8              Principal Title
# 9              Principal Title
# 10             Principal Title
# 11             Principal Title
# 12             Principal Title
# 13             Principal Title
# 14             Principal Title
# 15             Principal Title
# 16             Principal Title
# 17           Alternative Title
# 18           Alternative Title
# 19              Specialisation

# %% [markdown]
# # Methodologically sound, stepwise LLM-powered pipeline for noise detection

# %%
# --- 1. Install OpenAI library (quietly) ---
# !pip install openai --quiet

# %% [markdown]
# Cell 2: Load Unmatched Roles and API Key

# %%
# --- 2. Load unmatched roles and OpenAI API key ---
import pandas as pd
import os
from google.colab import userdata
from openai import OpenAI

# Load API key
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key
client = OpenAI()

# Load unmatched roles list
unmatched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_for_review.csv'
unmatched_df = pd.read_csv(unmatched_path)
roles_to_check = unmatched_df['Our_Role'].dropna().unique()

print(f"Total roles to review: {len(roles_to_check)}")
display(unmatched_df.head(10))
# Out:
# Total roles to review: 118
#                           Our_Role
# 0         Administration Assistant
# 1         Administrative Assistant
# 2   Analytics And Insights Manager
# 3              Analytics Developer
# 4          Apprentice Electricians
# 5  Artificial Intelligence Manager
# 6                   Asset Engineer
# 7    Assistant Ressources Humaines
# 8               Automation Manager
# 9             Automation Paralegal

# %% [markdown]
# Cell 3: Define Refined LLM Noise Check Prompt

# %%
# --- 3. Define LLM prompt for noise detection (English, knowledge work only) ---
def build_noise_check_prompt(role_name):
    return (
        "You are an expert in construction workforce and occupation classification in Australia. "
        f"Review the following entry: '{role_name}'.\n\n"
        "Does this represent a real job, profession, or legitimate occupational role related to knowledge work "
        "(rather than physical or site-based manual work) in the construction or built environment sector, and is the role title in English? "
        "If yes, reply 'Valid'. "
        "If not, reply 'Noise' and briefly explain why (e.g., not knowledge work, not English, placeholder, academic title, software, irrelevant to construction, etc.)."
    )

# %% [markdown]
# Cell 4: Run LLM Review on Each Unmatched Role

# %%
# --- 4. Review each unmatched role with LLM for noise detection ---
import time

results = []
for role in roles_to_check:
    user_prompt = build_noise_check_prompt(role)
    try:
        response = client.chat.completions.create(
            model="o3-mini",
            messages=[
                {"role": "system", "content": "You are an expert in the Australian construction workforce and occupation taxonomy."},
                {"role": "user", "content": user_prompt}
            ]
        )
        reply = response.choices[0].message.content.strip()
    except Exception as e:
        reply = f"Error: {e}"
    results.append({
        "Our_Role": role,
        "LLM_Review": reply
    })
    print(f"Reviewed: {role} | LLM: {reply}")
    time.sleep(1.2)  # Respect API rate limits

results_df = pd.DataFrame(results)
output_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_llm_noise_check.csv'
results_df.to_csv(output_path, index=False)
print(f"\nNoise-checked results saved to: {output_path}")

display(results_df.head(20))
# Out:
# Reviewed: Administration Assistant | LLM: Valid
# Reviewed: Administrative Assistant | LLM: Valid
# Reviewed: Analytics And Insights Manager | LLM: Valid
# Reviewed: Analytics Developer | LLM: Valid
# Reviewed: Apprentice Electricians | LLM: Noise – While Apprentice Electricians is a legitimate and real occupational role in the construction sector, it is primarily a manual, site‐based trade rather than a role focused on knowledge work.
# Reviewed: Artificial Intelligence Manager | LLM: Valid. The title is in English and implies a knowledge-based role that could logically exist within the construction or built environment sector, particularly as digital and AI technologies become more integrated into management and operational processes in the industry.
# Reviewed: Asset Engineer | LLM: Valid
# Reviewed: Assistant Ressources Humaines | LLM: Noise – The title is in French ("Assistant Ressources Humaines"), not English, even though it denotes a knowledge work role in Human Resources.
# Reviewed: Automation Manager | LLM: Valid
# Reviewed: Automation Paralegal | LLM: Noise – The title "Automation Paralegal" does not correspond to a recognized or established occupation within the construction/built environment sector. Although it is in English and implies knowledge work, the combination (paralegal with an automation focus) is not typical for construction-related roles and appears to be irrelevant to the sector’s occupational taxonomy.
# Reviewed: Automation Systems Engineer | LLM: Valid
# Reviewed: Bim Coordinator | LLM: Valid
# Reviewed: Bim Manager | LLM: Valid
# Reviewed: Bim Specialist | LLM: Valid. Bim Specialist is a legitimate knowledge work role within the construction sector related to Building Information Modeling, and the title is in English.
# Reviewed: Business Governance Manager | LLM: Valid
# Reviewed: Business Intelligence Developer | LLM: Valid
# Reviewed: Cadet | LLM: Noise – “Cadet” is too generic and lacks specificity. In the construction context, it doesn’t clearly indicate a knowledge work role and is typically used as part of a longer, more defined title (e.g., “Cadet Engineer”). Without further qualification, it isn’t a recognized occupational title in the built environment sector.
# Reviewed: Civil Project Engineer | LLM: Valid
# Reviewed: Commissioning Manager | LLM: Valid
#
# The role of Commissioning Manager is a recognized title in the construction and built environment sector. It typically involves oversight, planning, and management of the commissioning process, which is a knowledge-based function rather than a primarily manual or site-based one. The title is in English and aligns with labor taxonomies in construction.
# Reviewed: Completions Engineer | LLM: Valid
# Reviewed: Comptable | LLM: Noise – The term "Comptable" is a French word (meaning "accountant") and is not an English title, despite referring to a knowledge-based role in accounting.
# Reviewed: Conducteur De Travaux | LLM: Noise – The title is in French rather than English. While it relates to a construction role, the entry is not in English.
# Reviewed: Construction Superintendent | LLM: Valid. Construction Superintendent is a recognized role within the Australian construction and built environment sector, and the title is in English.
# Reviewed: Data Experts | LLM: Noise – "Data Experts" is too vague and generic. It does not clearly represent a formally recognized or established occupational title within the construction or built environment sector, even though it’s in English and hints at knowledge work.
# Reviewed: Data Graduate | LLM: Valid. The title is in English and implies a knowledge-focused role (typically involving data analytics or related functions) that would be part of a graduate program. While not exclusive to construction, companies in the built environment sector increasingly have such positions, making it a legitimate knowledge work role in that context.
# Reviewed: Data Science Manager | LLM: Valid
# Reviewed: Design Cadet | LLM: Valid
# Reviewed: Dessinateur Bureau Detudes | LLM: Noise – The title is in French ("Dessinateur Bureau d'Études") rather than English, which does not meet the requirement.
# Reviewed: Digital Engineering Manager | LLM: Valid
# Reviewed: Digital Intern | LLM: Noise – "Digital Intern" appears to be an informal or temporary internship role rather than a recognized, permanent occupational position related to knowledge work within the construction or built environment sector.
# Reviewed: Digital Optimization Analyst | LLM: Valid
# Reviewed: Director Of Data Management And Business Intelligence | LLM: Valid
# Reviewed: Document Controller | LLM: Valid
# Reviewed: Electrician Assistant | LLM: Noise – Although "Electrician Assistant" is a legitimate role in construction and the title is in English, it primarily involves manual, site-based tasks, not knowledge work.
# Reviewed: Electrician Team Leader | LLM: Noise – The title is in English and represents an actual construction trade role; however, an "Electrician Team Leader" is primarily a site-based/manual work position rather than a knowledge work role.
# Reviewed: Engineering Support Coordinator | LLM: Valid
# Reviewed: Enterprise Analyst | LLM: Valid
#
# Enterprise Analyst is a legitimate, English-language job title representing a knowledge work role. It typically involves business or data analysis at an enterprise level—functions that can be important in the construction or built environment sector (e.g., for managing complex projects, systems, and processes).
# Reviewed: Field Manager | LLM: Valid
# Reviewed: Finance Transformation Manager | LLM: Valid
# Reviewed: Graduate Program | LLM: Noise – "Graduate Program" is a training or development scheme, not a specific, legitimate occupational role in the construction sector.
# Reviewed: Graphic Design Intern | LLM: Noise – While "Graphic Design Intern" is a legitimate knowledge work role in English, it is a generic graphic design position that does not specifically relate to the construction or built environment sector.
# Reviewed: Group Manager Data And Iot | LLM: Valid
# Reviewed: House Coordinator | LLM: Noise – "House Coordinator" is not recognized as a legitimate, established occupational role within Australia's construction or built environment sector in the context of knowledge work.
# Reviewed: Hr Cadet | LLM: Valid
#
# The entry "Hr Cadet" is an English job title that represents a role in knowledge work (specifically within human resources) and can be legitimately associated with the construction or built environment sector, where corporate functions like HR are essential.
# Reviewed: Hse Advisor | LLM: Valid
# Reviewed: Human Resources And Safety Manager | LLM: Valid
# Reviewed: Information Systems Administrator | LLM: Valid
#
# "Information Systems Administrator" is a legitimate, English-language occupational role within knowledge work that can be applicable to the construction or built environment sector, particularly in managing IT infrastructure for organizations in that field.
# Reviewed: Insights Analyst | LLM: Valid
#
# "Insights Analyst" is a legitimate, English role title representing knowledge work, and it could be employed within the construction or built environment sector (e.g., for data-driven insights and decision-making) rather than representing site-based manual work.
# Reviewed: Iot Software Engineer | LLM: Valid
# Reviewed: It Support Team Leader | LLM: Valid
# Reviewed: Junior Automation Engineer | LLM: Valid
# Reviewed: Manager, Talent Advisory | LLM: Valid
# Reviewed: Monteur | LLM: Noise – The term "Monteur" is not in English and typically refers to a manual role (e.g., mechanic/installer) rather than a position classified as knowledge work in the construction or built environment sector.
# Reviewed: Monteur En Sécurité Incendie | LLM: Noise – The title is in French and refers to a more manual, site-based role rather than a knowledge-based occupation in the construction or built environment sector.
# Reviewed: Painters/Blasters | LLM: Noise – This role represents physical, site-based work in the construction industry rather than a knowledge work occupation.
# Reviewed: People Projects Lead | LLM: Valid
# Reviewed: People Projects Partner | LLM: Noise – The title is ambiguous and doesn’t clearly correspond to a recognized, construction-specific, knowledge-based occupational role. It appears more like a vague or internally branded corporate title (possibly relating to HR or project coordination) rather than a well-established job title within Australia’s built environment sector.
# Reviewed: Performance Marketing Analyst | LLM: Noise – The role "Performance Marketing Analyst" is a valid English job title, but it typically relates to digital marketing and analytics rather than knowledge work within the construction or built environment sector.
# Reviewed: Phd Position In Ai Techniques For Emergency Management And Critical Infrastructure | LLM: Noise – This entry is an academic PhD research position rather than a clearly defined knowledge work occupation within the construction or built environment sector.
# Reviewed: Pipeline Manager | LLM: Valid
# Reviewed: Planner | LLM: Valid
# Reviewed: Process Automation Specialist | LLM: Valid
# Reviewed: Procurement Business Partner | LLM: Valid
# Reviewed: Procurement Manager - Technology, Reporting And Analytics | LLM: Valid
# Reviewed: Production Planning Programmer | LLM: Noise – The title "Production Planning Programmer" isn't recognized as a standard knowledge work role in the construction or built environment sector. It combines terms that are typically seen in different fields (production planning and computer programming), making it ambiguous and not clearly linked to legitimate occupational roles in Australian construction workforce classifications.
# Reviewed: Project Administrative Assistant | LLM: Valid
# Reviewed: Project Engineer | LLM: Valid
# Reviewed: Property Analyst | LLM: Valid.
# Reviewed: Quality Advisor | LLM: Valid
# Reviewed: Reliability Associate | LLM: Noise – The title is vague and does not clearly correspond to a recognized, construction- or built environment–specific knowledge work role in the Australian context. It appears generic rather than a specific, legitimate occupational title in the sector.
# Reviewed: Reliability Engineer | LLM: Valid
# Reviewed: Responsable D'Affaires Services Sprinkler | LLM: Noise – The title is not in English; it appears to be French rather than a standard English-language occupational title.
# Reviewed: Risk Coordinator | LLM: Valid
# Reviewed: Safe Fme Developer | LLM: Noise – "Safe Fme Developer" does not match a recognized or standard job title in the Australian built environment sector. It seems unclear whether it's referring to a knowledge work role in construction, appears potentially as a mis-entry or placeholder, and is not clearly aligned with established occupational titles.
# Reviewed: Safety Advisor | LLM: Valid
# Reviewed: Secondary Design Sme | LLM: Noise – The title is unclear and ambiguous. "Secondary Design SME" does not clearly represent a recognized, formal knowledge work role in the construction or built environment sector, and it's not a standard occupational title used in the industry.
# Reviewed: Senior Analytics Engineer | LLM: Valid
# Reviewed: Senior Bi Analyst | LLM: Valid
#
# "Senior Bi Analyst" appears to be an English-language title for a knowledge work role (likely a shorthand for Senior Business Intelligence Analyst), which is a legitimate occupational role rather than physical manual work. While the connection to construction or the built environment might not be explicit, it could be applicable in data-driven roles within those sectors.
# Reviewed: Senior Contracts Administrator | LLM: Valid
# Reviewed: Senior Control Systems Engineer | LLM: Valid
# Reviewed: Senior Data Scientist | LLM: Valid
# Reviewed: Senior Insights Analyst | LLM: Valid
# Reviewed: Senior Planner | LLM: Valid
# Reviewed: Senior Project Controls And Risk Engineer | LLM: Valid
# Reviewed: Senior Project Engineer | LLM: Valid
# Reviewed: Senior Project Manager | LLM: Valid
# Reviewed: Senior Safety Advisor | LLM: Valid
# Reviewed: Senior Solution Engineer | LLM: Valid
# Reviewed: Senior Standards Engineer | LLM: Valid
# Reviewed: Senior Systems Engineer | LLM: Noise – Although "Senior Systems Engineer" is an English-language knowledge work title, it does not specifically indicate a role within the construction or built environment sector and is more indicative of an IT or technical systems role outside the scope of construction.
# Reviewed: Senior Technical Asset Manager | LLM: Valid
# Reviewed: Senior Technology Engineer | LLM: Valid
#
# Explanation: The title is in English and represents a knowledge-based engineering role. Although somewhat generic, "Senior Technology Engineer" can plausibly refer to a professional focused on technology within the construction or built environment sector, rather than a manual or on‐site physical position.
# Reviewed: Service Coordinator | LLM: Valid
# Reviewed: Service Planner | LLM: Valid
# Reviewed: Site Engineer | LLM: Valid
# Reviewed: Site Manager | LLM: Valid
# Reviewed: Solar Technician | LLM: Noise – "Solar Technician" is a real role in the construction/built environment sector, but it typically refers to a physically oriented position (involving installation and maintenance work) rather than a knowledge work role.
# Reviewed: Special Assets Officer | LLM: Noise – The title “Special Assets Officer” does not appear to be a recognized knowledge-based role specific to the construction or built environment sector; it instead suggests a different occupational area and is not clearly linked to construction work.
# Reviewed: Stagiaire Responsable D'Affaires | LLM: Noise – The title is in French rather than English and does not clearly relate to a construction knowledge work role.
# Reviewed: Study Manager | LLM: Noise – The title “Study Manager” is ambiguous and isn’t clearly established as a specific knowledge-based role within the construction or built environment sector. It is not a standard construction occupational title and, without additional context to tie it specifically to construction, it seems more likely to refer to a generic or research‐oriented role rather than a recognized construction profession.
# Reviewed: Subject Matter Expert | LLM: Valid
# Reviewed: Supervisor | LLM: Noise – "Supervisor" is too generic and typically refers to a site-based, manual supervisory role rather than a knowledge work role within the construction sector.
# Reviewed: Support Coordinator | LLM: Noise – The title “Support Coordinator” is too generic and ambiguous. It does not clearly indicate a knowledge work role specific to the construction or built environment sector (and may instead refer to support functions in other sectors such as healthcare or social services).
# Reviewed: Sustainability Coordinator | LLM: Valid
# Reviewed: Talent Acquisition Project Manager | LLM: Valid
# Reviewed: Talent Acquisition Systems Specialist | LLM: Valid. This title is in English and denotes a knowledge work role—focused on managing recruitment systems—that could feasibly exist within a construction or built environment organization’s HR or corporate functions.
# Reviewed: Talent Sourcing Analyst | LLM: Valid
# Reviewed: Technical Project Leader | LLM: Valid
#
# "Technical Project Leader" is a role title in English, and it represents a legitimate occupational position within the construction or built environment sector. The role emphasizes knowledge work and project management responsibilities, distinguishing it from purely physical or manual site-based work.
# Reviewed: Telecommunications Assistant | LLM: Noise – While "Telecommunications Assistant" is an English job title and can be a legitimate role in telecom-related fields, it typically describes a support or technician-type position often involving on-site or manual, implementation work rather than primarily knowledge-based work.
# Reviewed: Telecommunicator | LLM: Noise – "Telecommunicator" is an English title referring to a role typically associated with telecommunications or emergency dispatch, not a recognized construction or built environment knowledge work occupation.
# Reviewed: Tmp-A | LLM: Noise – The entry “Tmp-A” does not represent a clear, legitimate occupational title in the construction or built environment sector. It appears to be a placeholder or abbreviated code rather than a real knowledge work role in English.
# Reviewed: Trade Assistant | LLM: Noise – The title "Trade Assistant" refers to a role that primarily supports manual/trade work rather than a knowledge-based occupation in construction.
# Reviewed: Traffic Manager | LLM: Valid
# Reviewed: Undergraduate | LLM: Noise – "Undergraduate" is an academic classification, not a recognized occupational role or knowledge work position within the construction sector.
# Reviewed: Vendor Administrator | LLM: Valid
# Reviewed: Warranty Engineer | LLM: Valid. "Warranty Engineer" is a legitimate, English job title in the construction or built environment sector, typically involving technical and knowledge-based work related to warranty analysis and management.
# Reviewed: Workforce Participation Manager | LLM: Valid
# Reviewed: Workplace Experience Manager | LLM: Valid
#
# Noise-checked results saved to: /content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_llm_noise_check.csv
#                            Our_Role  \
# 0          Administration Assistant
# 1          Administrative Assistant
# 2    Analytics And Insights Manager
# 3               Analytics Developer
# 4           Apprentice Electricians
# 5   Artificial Intelligence Manager
# 6                    Asset Engineer
# 7     Assistant Ressources Humaines
# 8                Automation Manager
# 9              Automation Paralegal
# 10      Automation Systems Engineer
# 11                  Bim Coordinator
# 12                      Bim Manager
# 13                   Bim Specialist
# 14      Business Governance Manager
# 15  Business Intelligence Developer
# 16                            Cadet
# 17           Civil Project Engineer
# 18            Commissioning Manager
# 19             Completions Engineer
#
#                                            LLM_Review
# 0                                               Valid
# 1                                               Valid
# 2                                               Valid
# 3                                               Valid
# 4   Noise – While Apprentice Electricians is a leg...
# 5   Valid. The title is in English and implies a k...
# 6                                               Valid
# 7   Noise – The title is in French ("Assistant Res...
# 8                                               Valid
# 9   Noise – The title "Automation Paralegal" does ...
# 10                                              Valid
# 11                                              Valid
# 12                                              Valid
# 13  Valid. Bim Specialist is a legitimate knowledg...
# 14                                              Valid
# 15                                              Valid
# 16  Noise – “Cadet” is too generic and lacks speci...
# 17                                              Valid
# 18  Valid\n\nThe role of Commissioning Manager is ...
# 19                                              Valid

# %% [markdown]
# # Deleting “Noise” roles from your graph

# %% [markdown]
# Cell 1: Isolate the “Noise” Roles List for Deletion

# %%
# --- 1. Isolate Noise Roles for Deletion (Robust Encoding) ---
import pandas as pd

noise_file = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_llm_noise_check.csv'

# Try UTF-8 first, then fall back to latin1 if needed
try:
    noise_df = pd.read_csv(noise_file, encoding='utf-8-sig')
except UnicodeDecodeError:
    noise_df = pd.read_csv(noise_file, encoding='latin1')

# Extract only roles where LLM_Review begins with "Noise"
noise_roles = noise_df[noise_df['LLM_Review'].str.lower().str.startswith('noise')]['Our_Role'].dropna().unique().tolist()

print(f"Roles identified as 'Noise': {len(noise_roles)}")
print("Sample noise roles:", noise_roles[:10])
# --- Checkpoint: Review the list above. Approve before proceeding. ---
# Out:
# Roles identified as 'Noise': 38
# Sample noise roles: ['Apprentice Electricians', 'Assistant Ressources Humaines', 'Automation Paralegal', 'Cadet', 'Comptable', 'Conducteur De Travaux', 'Data Experts', 'Dessinateur Bureau Detudes', 'Digital Intern', 'Electrician Assistant']

# %% [markdown]
# Cell 2: Dry Run — Check Existence and Relationships for Each Target Role

# %%
# --- 2. Dry Run: Check Existence and Relationships for Target Roles ---
print("Dry run — Reviewing nodes and their relationships (no deletions will be made):\n")

from collections import defaultdict

found_nodes = []
not_found_nodes = []
node_rel_summary = defaultdict(list)

for role_name in noise_roles:
    role_nodes = [
        n for n, d in G.nodes(data=True)
        if d.get('labels') == ':Role' and d.get('id') == role_name
    ]
    if not role_nodes:
        not_found_nodes.append(role_name)
        continue
    found_nodes.append(role_name)
    node = role_nodes[0]
    rels = list(G.edges(node, data=True)) + list(G.in_edges(node, data=True))
    node_rel_summary[role_name] = rels
    print(f"Role '{role_name}' found. Total relationships: {len(rels)}")
    for src, tgt, data in rels:
        print(f"  {src} -> {tgt} | {data}")

print(f"\nTotal roles found for deletion: {len(found_nodes)}")
print(f"Roles NOT found in graph: {not_found_nodes}")
# --- Checkpoint: Review the printout to confirm these are the intended nodes for deletion. ---
# Out:
# Dry run — Reviewing nodes and their relationships (no deletions will be made):
#
# Role 'Apprentice Electricians' found. Total relationships: 5
#   n736 -> n738 | {'label': 'REQUIRES_SKILL'}
#   n736 -> n739 | {'label': 'REQUIRES_SKILL'}
#   n736 -> n740 | {'label': 'REQUIRES_SKILL'}
#   n736 -> n741 | {'label': 'REQUIRES_SKILL'}
#   n736 -> n737 | {'label': 'PERFORMS_TASK'}
# Role 'Assistant Ressources Humaines' found. Total relationships: 7
#   n1864 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n1864 -> n1869 | {'label': 'REQUIRES_SKILL'}
#   n1864 -> n1870 | {'label': 'REQUIRES_SKILL'}
#   n1864 -> n1871 | {'label': 'REQUIRES_SKILL'}
#   n1864 -> n1865 | {'label': 'PERFORMS_TASK'}
#   n1864 -> n1866 | {'label': 'PERFORMS_TASK'}
#   n1864 -> n1867 | {'label': 'PERFORMS_TASK'}
# Role 'Automation Paralegal' found. Total relationships: 6
#   n1321 -> n74 | {'label': 'REQUIRES_SKILL'}
#   n1321 -> n1328 | {'label': 'REQUIRES_SKILL'}
#   n1321 -> n443 | {'label': 'USES_TOOL'}
#   n1321 -> n1329 | {'label': 'USES_TOOL'}
#   n1321 -> n1330 | {'label': 'USES_TOOL'}
#   n1321 -> n1322 | {'label': 'PERFORMS_TASK'}
# Role 'Cadet' found. Total relationships: 8
#   n420 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n420 -> n273 | {'label': 'REQUIRES_SKILL'}
#   n420 -> n421 | {'label': 'REQUIRES_SKILL'}
#   n420 -> n422 | {'label': 'REQUIRES_SKILL'}
#   n420 -> n423 | {'label': 'REQUIRES_SKILL'}
#   n420 -> n604 | {'label': 'REQUIRES_SKILL'}
#   n420 -> n219 | {'label': 'PERFORMS_TASK'}
#   n420 -> n596 | {'label': 'PERFORMS_TASK'}
# Role 'Comptable' found. Total relationships: 5
#   n2117 -> n1847 | {'label': 'USES_TOOL'}
#   n2117 -> n2118 | {'label': 'PERFORMS_TASK'}
#   n2117 -> n2119 | {'label': 'PERFORMS_TASK'}
#   n2117 -> n2120 | {'label': 'PERFORMS_TASK'}
#   n2117 -> n911 | {'label': 'REQUIRES_TOOL'}
# Role 'Conducteur De Travaux' found. Total relationships: 9
#   n1837 -> n1838 | {'label': 'REQUIRES_SKILL'}
#   n1837 -> n1839 | {'label': 'REQUIRES_SKILL'}
#   n1837 -> n1841 | {'label': 'PERFORMS_TASK'}
#   n1837 -> n1842 | {'label': 'PERFORMS_TASK'}
#   n1837 -> n1843 | {'label': 'PERFORMS_TASK'}
#   n1837 -> n1844 | {'label': 'PERFORMS_TASK'}
#   n1837 -> n1845 | {'label': 'PERFORMS_TASK'}
#   n1837 -> n1846 | {'label': 'PERFORMS_TASK'}
#   n1837 -> n1847 | {'label': 'REQUIRES_TOOL'}
# Role 'Data Experts' found. Total relationships: 4
#   n1045 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n1045 -> n1047 | {'label': 'REQUIRES_SKILL'}
#   n1045 -> n1048 | {'label': 'REQUIRES_SKILL'}
#   n1045 -> n1046 | {'label': 'PERFORMS_TASK'}
# Role 'Dessinateur Bureau Detudes' found. Total relationships: 13
#   n1814 -> n1124 | {'label': 'REQUIRES_SKILL'}
#   n1814 -> n1817 | {'label': 'REQUIRES_SKILL'}
#   n1814 -> n1818 | {'label': 'REQUIRES_SKILL'}
#   n1814 -> n1819 | {'label': 'REQUIRES_SKILL'}
#   n1814 -> n1820 | {'label': 'REQUIRES_SKILL'}
#   n1814 -> n1821 | {'label': 'REQUIRES_SKILL'}
#   n1814 -> n244 | {'label': 'USES_TOOL'}
#   n1814 -> n1827 | {'label': 'USES_TOOL'}
#   n1814 -> n1822 | {'label': 'PERFORMS_TASK'}
#   n1814 -> n1823 | {'label': 'PERFORMS_TASK'}
#   n1814 -> n1824 | {'label': 'PERFORMS_TASK'}
#   n1814 -> n1825 | {'label': 'PERFORMS_TASK'}
#   n1814 -> n1826 | {'label': 'PERFORMS_TASK'}
# Role 'Digital Intern' found. Total relationships: 20
#   n1258 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n149 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n186 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n250 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n307 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n1259 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n1265 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n1993 | {'label': 'REQUIRES_SKILL'}
#   n1258 -> n1260 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1261 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1262 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1263 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1264 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1266 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1267 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1268 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1506 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1992 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1994 | {'label': 'PERFORMS_TASK'}
#   n1258 -> n1995 | {'label': 'PERFORMS_TASK'}
# Role 'Electrician Assistant' found. Total relationships: 22
#   n256 -> n45 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n47 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n257 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n258 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n259 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n260 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n261 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n262 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n263 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n264 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n269 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n270 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n271 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n272 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n273 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n277 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n278 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n279 | {'label': 'REQUIRES_SKILL'}
#   n256 -> n268 | {'label': 'PERFORMS_TASK'}
#   n256 -> n274 | {'label': 'PERFORMS_TASK'}
#   n256 -> n275 | {'label': 'PERFORMS_TASK'}
#   n256 -> n276 | {'label': 'PERFORMS_TASK'}
# Role 'Electrician Team Leader' found. Total relationships: 17
#   n1316 -> n277 | {'label': 'REQUIRES_SKILL'}
#   n1316 -> n872 | {'label': 'REQUIRES_SKILL'}
#   n1316 -> n873 | {'label': 'REQUIRES_SKILL'}
#   n1316 -> n923 | {'label': 'REQUIRES_SKILL'}
#   n1316 -> n997 | {'label': 'REQUIRES_SKILL'}
#   n1316 -> n1320 | {'label': 'REQUIRES_SKILL'}
#   n1316 -> n544 | {'label': 'USES_TOOL'}
#   n1316 -> n545 | {'label': 'USES_TOOL'}
#   n1316 -> n225 | {'label': 'PERFORMS_TASK'}
#   n1316 -> n1317 | {'label': 'PERFORMS_TASK'}
#   n1316 -> n1318 | {'label': 'PERFORMS_TASK'}
#   n261 -> n1316 | {'label': 'REQUIRES_SKILL'}
#   n262 -> n1316 | {'label': 'REQUIRES_SKILL'}
#   n544 -> n1316 | {'label': 'USES_TOOL'}
#   n545 -> n1316 | {'label': 'USES_TOOL'}
#   n1319 -> n1316 | {'label': 'REQUIRES_SKILL'}
#   n1320 -> n1316 | {'label': 'REQUIRES_SKILL'}
# Role 'Graduate Program' found. Total relationships: 18
#   n1354 -> n188 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n406 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n598 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1364 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1365 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1366 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1367 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1368 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1369 | {'label': 'REQUIRES_SKILL'}
#   n1354 -> n1355 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1356 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1357 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1358 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1359 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1360 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1361 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1362 | {'label': 'PERFORMS_TASK'}
#   n1354 -> n1363 | {'label': 'PERFORMS_TASK'}
# Role 'Graphic Design Intern' found. Total relationships: 9
#   n1986 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n1986 -> n75 | {'label': 'REQUIRES_SKILL'}
#   n1986 -> n142 | {'label': 'REQUIRES_SKILL'}
#   n1986 -> n434 | {'label': 'REQUIRES_SKILL'}
#   n1986 -> n859 | {'label': 'USES_TOOL'}
#   n1986 -> n1987 | {'label': 'PERFORMS_TASK'}
#   n1986 -> n1988 | {'label': 'PERFORMS_TASK'}
#   n1986 -> n1989 | {'label': 'PERFORMS_TASK'}
#   n1986 -> n1990 | {'label': 'PERFORMS_TASK'}
# Role 'House Coordinator' found. Total relationships: 8
#   n2379 -> n2380 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2381 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2382 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2383 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2384 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2385 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2386 | {'label': 'PERFORMS_TASK'}
#   n2379 -> n2387 | {'label': 'PERFORMS_TASK'}
# Role 'Monteur' found. Total relationships: 6
#   n1829 -> n1834 | {'label': 'REQUIRES_SKILL'}
#   n1829 -> n1836 | {'label': 'REQUIRES_SKILL'}
#   n1829 -> n1830 | {'label': 'PERFORMS_TASK'}
#   n1829 -> n1831 | {'label': 'PERFORMS_TASK'}
#   n1829 -> n1832 | {'label': 'PERFORMS_TASK'}
#   n1829 -> n1833 | {'label': 'PERFORMS_TASK'}
# Role 'Painters/Blasters' found. Total relationships: 8
#   n1774 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n1774 -> n45 | {'label': 'REQUIRES_SKILL'}
#   n1774 -> n1775 | {'label': 'PERFORMS_TASK'}
#   n1774 -> n1776 | {'label': 'PERFORMS_TASK'}
#   n1774 -> n1781 | {'label': 'REQUIRES_TOOL'}
#   n1774 -> n1782 | {'label': 'REQUIRES_TOOL'}
#   n1774 -> n1783 | {'label': 'REQUIRES_TOOL'}
#   n1774 -> n1784 | {'label': 'REQUIRES_TOOL'}
# Role 'People Projects Partner' found. Total relationships: 11
#   n1658 -> n142 | {'label': 'REQUIRES_SKILL'}
#   n1658 -> n1202 | {'label': 'REQUIRES_SKILL'}
#   n1658 -> n1429 | {'label': 'REQUIRES_SKILL'}
#   n1658 -> n1430 | {'label': 'REQUIRES_SKILL'}
#   n1658 -> n1423 | {'label': 'PERFORMS_TASK'}
#   n1658 -> n1659 | {'label': 'PERFORMS_TASK'}
#   n1658 -> n1660 | {'label': 'PERFORMS_TASK'}
#   n1658 -> n1661 | {'label': 'PERFORMS_TASK'}
#   n1658 -> n1662 | {'label': 'PERFORMS_TASK'}
#   n1658 -> n1663 | {'label': 'PERFORMS_TASK'}
#   n1658 -> n1664 | {'label': 'PERFORMS_TASK'}
# Role 'Performance Marketing Analyst' found. Total relationships: 13
#   n1495 -> n171 | {'label': 'REQUIRES_SKILL'}
#   n1495 -> n1499 | {'label': 'REQUIRES_SKILL'}
#   n1495 -> n1500 | {'label': 'REQUIRES_SKILL'}
#   n1495 -> n1501 | {'label': 'REQUIRES_SKILL'}
#   n1495 -> n1502 | {'label': 'REQUIRES_SKILL'}
#   n1495 -> n12 | {'label': 'USES_TOOL'}
#   n1495 -> n1454 | {'label': 'USES_TOOL'}
#   n1495 -> n1455 | {'label': 'USES_TOOL'}
#   n1495 -> n1456 | {'label': 'USES_TOOL'}
#   n1495 -> n1503 | {'label': 'USES_TOOL'}
#   n1495 -> n166 | {'label': 'PERFORMS_TASK'}
#   n1495 -> n1496 | {'label': 'PERFORMS_TASK'}
#   n1495 -> n1497 | {'label': 'PERFORMS_TASK'}
# Role 'Phd Position In Ai Techniques For Emergency Management And Critical Infrastructure' found. Total relationships: 6
#   n1872 -> n1699 | {'label': 'REQUIRES_SKILL'}
#   n1872 -> n1874 | {'label': 'REQUIRES_SKILL'}
#   n1872 -> n1875 | {'label': 'REQUIRES_SKILL'}
#   n1872 -> n1876 | {'label': 'REQUIRES_SKILL'}
#   n1872 -> n1878 | {'label': 'REQUIRES_SKILL'}
#   n1872 -> n1873 | {'label': 'PERFORMS_TASK'}
# Role 'Production Planning Programmer' found. Total relationships: 8
#   n483 -> n484 | {'label': 'REQUIRES_SKILL'}
#   n483 -> n488 | {'label': 'REQUIRES_SKILL'}
#   n483 -> n489 | {'label': 'REQUIRES_SKILL'}
#   n483 -> n497 | {'label': 'USES_TOOL'}
#   n483 -> n498 | {'label': 'USES_TOOL'}
#   n483 -> n499 | {'label': 'USES_TOOL'}
#   n483 -> n492 | {'label': 'PERFORMS_TASK'}
#   n483 -> n496 | {'label': 'PERFORMS_TASK'}
# Role 'Reliability Associate' found. Total relationships: 16
#   n458 -> n368 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n369 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n465 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n466 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n467 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n468 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n469 | {'label': 'REQUIRES_SKILL'}
#   n458 -> n381 | {'label': 'USES_TOOL'}
#   n458 -> n382 | {'label': 'USES_TOOL'}
#   n458 -> n383 | {'label': 'USES_TOOL'}
#   n458 -> n459 | {'label': 'PERFORMS_TASK'}
#   n458 -> n460 | {'label': 'PERFORMS_TASK'}
#   n458 -> n461 | {'label': 'PERFORMS_TASK'}
#   n458 -> n462 | {'label': 'PERFORMS_TASK'}
#   n458 -> n380 | {'label': 'REQUIRES_TOOL'}
#   n457 -> n458 | {'label': 'REQUIRES_EXPERIENCE'}
# Role 'Responsable D'Affaires Services Sprinkler' found. Total relationships: 11
#   n2154 -> n2161 | {'label': 'REQUIRES_SKILL'}
#   n2154 -> n2162 | {'label': 'REQUIRES_SKILL'}
#   n2154 -> n2163 | {'label': 'REQUIRES_SKILL'}
#   n2154 -> n2164 | {'label': 'REQUIRES_SKILL'}
#   n2154 -> n2155 | {'label': 'PERFORMS_TASK'}
#   n2154 -> n2156 | {'label': 'PERFORMS_TASK'}
#   n2154 -> n2157 | {'label': 'PERFORMS_TASK'}
#   n2154 -> n2158 | {'label': 'PERFORMS_TASK'}
#   n2154 -> n2159 | {'label': 'PERFORMS_TASK'}
#   n2154 -> n2160 | {'label': 'PERFORMS_TASK'}
#   n2154 -> n2166 | {'label': 'REQUIRES_TOOL'}
# Role 'Safe Fme Developer' found. Total relationships: 5
#   n975 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n975 -> n32 | {'label': 'REQUIRES_SKILL'}
#   n975 -> n75 | {'label': 'REQUIRES_SKILL'}
#   n975 -> n979 | {'label': 'USES_TOOL'}
#   n975 -> n976 | {'label': 'PERFORMS_TASK'}
# Role 'Secondary Design Sme' found. Total relationships: 9
#   n1485 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n1485 -> n32 | {'label': 'REQUIRES_SKILL'}
#   n1485 -> n45 | {'label': 'REQUIRES_SKILL'}
#   n1485 -> n580 | {'label': 'REQUIRES_SKILL'}
#   n1485 -> n1061 | {'label': 'REQUIRES_SKILL'}
#   n1485 -> n1489 | {'label': 'REQUIRES_SKILL'}
#   n1485 -> n1486 | {'label': 'PERFORMS_TASK'}
#   n1485 -> n1487 | {'label': 'PERFORMS_TASK'}
#   n1485 -> n1488 | {'label': 'PERFORMS_TASK'}
# Role 'Senior Systems Engineer' found. Total relationships: 12
#   n768 -> n580 | {'label': 'REQUIRES_SKILL'}
#   n768 -> n584 | {'label': 'REQUIRES_SKILL'}
#   n768 -> n585 | {'label': 'REQUIRES_SKILL'}
#   n768 -> n591 | {'label': 'REQUIRES_SKILL'}
#   n768 -> n613 | {'label': 'REQUIRES_SKILL'}
#   n768 -> n769 | {'label': 'REQUIRES_SKILL'}
#   n768 -> n592 | {'label': 'USES_TOOL'}
#   n768 -> n593 | {'label': 'USES_TOOL'}
#   n768 -> n586 | {'label': 'PERFORMS_TASK'}
#   n768 -> n587 | {'label': 'PERFORMS_TASK'}
#   n768 -> n588 | {'label': 'PERFORMS_TASK'}
#   n768 -> n589 | {'label': 'PERFORMS_TASK'}
# Role 'Solar Technician' found. Total relationships: 15
#   n940 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n45 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n261 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n263 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n273 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n278 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n827 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n943 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n944 | {'label': 'REQUIRES_SKILL'}
#   n940 -> n445 | {'label': 'USES_TOOL'}
#   n940 -> n446 | {'label': 'USES_TOOL'}
#   n940 -> n544 | {'label': 'USES_TOOL'}
#   n940 -> n545 | {'label': 'USES_TOOL'}
#   n940 -> n941 | {'label': 'PERFORMS_TASK'}
#   n940 -> n942 | {'label': 'PERFORMS_TASK'}
# Role 'Special Assets Officer' found. Total relationships: 4
#   n474 -> n481 | {'label': 'USES_TOOL'}
#   n474 -> n482 | {'label': 'USES_TOOL'}
#   n474 -> n475 | {'label': 'PERFORMS_TASK'}
#   n474 -> n476 | {'label': 'PERFORMS_TASK'}
# Role 'Stagiaire Responsable D'Affaires' found. Total relationships: 9
#   n2123 -> n282 | {'label': 'REQUIRES_SKILL'}
#   n2123 -> n329 | {'label': 'REQUIRES_SKILL'}
#   n2123 -> n603 | {'label': 'REQUIRES_SKILL'}
#   n2123 -> n933 | {'label': 'REQUIRES_SKILL'}
#   n2123 -> n2127 | {'label': 'REQUIRES_SKILL'}
#   n2123 -> n2124 | {'label': 'PERFORMS_TASK'}
#   n2123 -> n2125 | {'label': 'PERFORMS_TASK'}
#   n2123 -> n2126 | {'label': 'PERFORMS_TASK'}
#   n2123 -> n1281 | {'label': 'REQUIRES_TOOL'}
# Role 'Study Manager' found. Total relationships: 15
#   n384 -> n118 | {'label': 'REQUIRES_SKILL'}
#   n384 -> n397 | {'label': 'REQUIRES_SKILL'}
#   n384 -> n398 | {'label': 'REQUIRES_SKILL'}
#   n384 -> n385 | {'label': 'PERFORMS_TASK'}
#   n384 -> n386 | {'label': 'PERFORMS_TASK'}
#   n384 -> n387 | {'label': 'PERFORMS_TASK'}
#   n384 -> n388 | {'label': 'PERFORMS_TASK'}
#   n384 -> n389 | {'label': 'PERFORMS_TASK'}
#   n384 -> n390 | {'label': 'PERFORMS_TASK'}
#   n384 -> n391 | {'label': 'PERFORMS_TASK'}
#   n384 -> n392 | {'label': 'PERFORMS_TASK'}
#   n384 -> n393 | {'label': 'PERFORMS_TASK'}
#   n384 -> n394 | {'label': 'PERFORMS_TASK'}
#   n384 -> n395 | {'label': 'REQUIRES_EXPERIENCE'}
#   n384 -> n396 | {'label': 'REQUIRES_EXPERIENCE'}
# Role 'Subject Matter Expert' found. Total relationships: 7
#   n1526 -> n118 | {'label': 'REQUIRES_SKILL'}
#   n1526 -> n580 | {'label': 'REQUIRES_SKILL'}
#   n1526 -> n1061 | {'label': 'REQUIRES_SKILL'}
#   n1526 -> n1489 | {'label': 'REQUIRES_SKILL'}
#   n1526 -> n1486 | {'label': 'PERFORMS_TASK'}
#   n1526 -> n1487 | {'label': 'PERFORMS_TASK'}
#   n1526 -> n1527 | {'label': 'PERFORMS_TASK'}
# Role 'Supervisor' found. Total relationships: 15
#   n2168 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n75 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n250 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n273 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n479 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n2182 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n2183 | {'label': 'REQUIRES_SKILL'}
#   n2168 -> n1356 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n1833 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n2169 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n2170 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n2171 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n2172 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n2180 | {'label': 'PERFORMS_TASK'}
#   n2168 -> n2181 | {'label': 'PERFORMS_TASK'}
# Role 'Support Coordinator' found. Total relationships: 7
#   n1640 -> n171 | {'label': 'REQUIRES_SKILL'}
#   n1640 -> n1643 | {'label': 'REQUIRES_SKILL'}
#   n1640 -> n1644 | {'label': 'REQUIRES_SKILL'}
#   n1640 -> n1647 | {'label': 'USES_TOOL'}
#   n1640 -> n1648 | {'label': 'USES_TOOL'}
#   n1640 -> n1641 | {'label': 'PERFORMS_TASK'}
#   n1640 -> n1642 | {'label': 'PERFORMS_TASK'}
# Role 'Telecommunications Assistant' found. Total relationships: 22
#   n500 -> n257 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n258 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n259 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n260 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n261 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n262 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n263 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n264 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n269 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n270 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n271 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n272 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n453 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n455 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n546 | {'label': 'REQUIRES_SKILL'}
#   n500 -> n445 | {'label': 'USES_TOOL'}
#   n500 -> n446 | {'label': 'USES_TOOL'}
#   n500 -> n447 | {'label': 'USES_TOOL'}
#   n500 -> n268 | {'label': 'PERFORMS_TASK'}
#   n500 -> n274 | {'label': 'PERFORMS_TASK'}
#   n500 -> n275 | {'label': 'PERFORMS_TASK'}
#   n500 -> n276 | {'label': 'PERFORMS_TASK'}
# Role 'Telecommunicator' found. Total relationships: 32
#   n614 -> n45 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n47 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n261 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n262 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n263 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n277 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n278 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n453 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n454 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n455 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n615 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n616 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n770 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n871 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n872 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n873 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n874 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n875 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n876 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n877 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n878 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n997 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n998 | {'label': 'REQUIRES_SKILL'}
#   n614 -> n445 | {'label': 'USES_TOOL'}
#   n614 -> n446 | {'label': 'USES_TOOL'}
#   n614 -> n447 | {'label': 'USES_TOOL'}
#   n614 -> n544 | {'label': 'USES_TOOL'}
#   n614 -> n545 | {'label': 'USES_TOOL'}
#   n614 -> n268 | {'label': 'PERFORMS_TASK'}
#   n614 -> n870 | {'label': 'PERFORMS_TASK'}
#   n614 -> n996 | {'label': 'PERFORMS_TASK'}
#   n614 -> n1281 | {'label': 'REQUIRES_TOOL'}
# Role 'Tmp-A' found. Total relationships: 1
#   n2424 -> n2425 | {'label': 'TEST'}
# Role 'Trade Assistant' found. Total relationships: 12
#   n283 -> n3 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n45 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n284 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n285 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n286 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n287 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n288 | {'label': 'REQUIRES_SKILL'}
#   n283 -> n289 | {'label': 'PERFORMS_TASK'}
#   n283 -> n290 | {'label': 'PERFORMS_TASK'}
#   n283 -> n291 | {'label': 'PERFORMS_TASK'}
#   n283 -> n292 | {'label': 'PERFORMS_TASK'}
#   n283 -> n293 | {'label': 'PERFORMS_TASK'}
# Role 'Undergraduate' found. Total relationships: 7
#   n889 -> n334 | {'label': 'REQUIRES_SKILL'}
#   n889 -> n421 | {'label': 'REQUIRES_SKILL'}
#   n889 -> n422 | {'label': 'REQUIRES_SKILL'}
#   n889 -> n597 | {'label': 'REQUIRES_SKILL'}
#   n889 -> n598 | {'label': 'REQUIRES_SKILL'}
#   n889 -> n599 | {'label': 'REQUIRES_SKILL'}
#   n889 -> n890 | {'label': 'PERFORMS_TASK'}
#
# Total roles found for deletion: 37
# Roles NOT found in graph: ['Monteur En SÃ©curitÃ© Incendie']

# %%
# --- Search for variants of 'Monteur En Sécurité Incendie' ---
suspect_fragment = "Monteur En"
possible_matches = [
    (n, d.get('id')) for n, d in G.nodes(data=True)
    if d.get('labels') == ':Role' and d.get('id') and suspect_fragment.lower() in d.get('id').lower()
]

print("Possible graph nodes matching or resembling 'Monteur En Sécurité Incendie':")
for node_key, node_id in possible_matches:
    print(f"Graph node: {node_key}, id: '{node_id}'")
# Out:
# Possible graph nodes matching or resembling 'Monteur En Sécurité Incendie':
# Graph node: n1803, id: 'Monteur En Sécurité Incendie'

# %%
# --- Patch noise_roles list for proper encoding ---
# Remove garbled entry if present
noise_roles = [r for r in noise_roles if 'monteur en' not in r.lower()]
# Add correct version
noise_roles.append('Monteur En Sécurité Incendie')
print("'Monteur En Sécurité Incendie' added to deletion list.")
# Out:
# 'Monteur En Sécurité Incendie' added to deletion list.

# %% [markdown]
# Cell 3: Perform Safe DETACH DELETE of Noise Roles from Graph

# %%
# --- 3. Delete Noise Roles from Graph (with DETACH logic) ---
print("Deleting confirmed 'Noise' roles from the graph...")

deleted = 0
for role_name in noise_roles:
    role_nodes = [
        n for n, d in G.nodes(data=True)
        if d.get('labels') == ':Role' and d.get('id') == role_name
    ]
    if not role_nodes:
        continue
    node = role_nodes[0]
    # Remove all edges (DETACH logic)
    G.remove_edges_from(list(G.out_edges(node)))
    G.remove_edges_from(list(G.in_edges(node)))
    # Now remove the node itself
    G.remove_node(node)
    print(f"Deleted node '{role_name}' and its relationships.")
    deleted += 1

print(f"\nTotal roles deleted: {deleted}")
# Out:
# Deleting confirmed 'Noise' roles from the graph...
# Deleted node 'Apprentice Electricians' and its relationships.
# Deleted node 'Assistant Ressources Humaines' and its relationships.
# Deleted node 'Automation Paralegal' and its relationships.
# Deleted node 'Cadet' and its relationships.
# Deleted node 'Comptable' and its relationships.
# Deleted node 'Conducteur De Travaux' and its relationships.
# Deleted node 'Data Experts' and its relationships.
# Deleted node 'Dessinateur Bureau Detudes' and its relationships.
# Deleted node 'Digital Intern' and its relationships.
# Deleted node 'Electrician Assistant' and its relationships.
# Deleted node 'Electrician Team Leader' and its relationships.
# Deleted node 'Graduate Program' and its relationships.
# Deleted node 'Graphic Design Intern' and its relationships.
# Deleted node 'House Coordinator' and its relationships.
# Deleted node 'Monteur' and its relationships.
# Deleted node 'Painters/Blasters' and its relationships.
# Deleted node 'People Projects Partner' and its relationships.
# Deleted node 'Performance Marketing Analyst' and its relationships.
# Deleted node 'Phd Position In Ai Techniques For Emergency Management And Critical Infrastructure' and its relationships.
# Deleted node 'Production Planning Programmer' and its relationships.
# Deleted node 'Reliability Associate' and its relationships.
# Deleted node 'Responsable D'Affaires Services Sprinkler' and its relationships.
# Deleted node 'Safe Fme Developer' and its relationships.
# Deleted node 'Secondary Design Sme' and its relationships.
# Deleted node 'Senior Systems Engineer' and its relationships.
# Deleted node 'Solar Technician' and its relationships.
# Deleted node 'Special Assets Officer' and its relationships.
# Deleted node 'Stagiaire Responsable D'Affaires' and its relationships.
# Deleted node 'Study Manager' and its relationships.
# Deleted node 'Subject Matter Expert' and its relationships.
# Deleted node 'Supervisor' and its relationships.
# Deleted node 'Support Coordinator' and its relationships.
# Deleted node 'Telecommunications Assistant' and its relationships.
# Deleted node 'Telecommunicator' and its relationships.
# Deleted node 'Tmp-A' and its relationships.
# Deleted node 'Trade Assistant' and its relationships.
# Deleted node 'Undergraduate' and its relationships.
# Deleted node 'Monteur En Sécurité Incendie' and its relationships.
#
# Total roles deleted: 38

# %%
import pickle

with open('/content/drive/MyDrive/knowledge-graph-llms/cleaned_graph_after_noise_removal.gpickle', 'wb') as f:
    pickle.dump(G, f)

print("Cleaned graph saved as pickle.")
# Out:
# Cleaned graph saved as pickle.

# %%
nx.write_graphml(G, '/content/drive/MyDrive/knowledge-graph-llms/cleaned_graph_after_noise_removal.graphml')
print("Cleaned graph saved as GraphML.")
# Out:
# Cleaned graph saved as GraphML.

# %% [markdown]
# Summary Statistics for the Cleaned Graph

# %%
# --- Overview of Cleaned Graph ---
from collections import Counter

node_labels = [d.get('labels', 'UNKNOWN') for _, d in G.nodes(data=True)]
node_label_counts = Counter(node_labels)

edge_labels = [d.get('label', 'UNKNOWN') for _, _, d in G.edges(data=True)]
edge_label_counts = Counter(edge_labels)

print(f"Total nodes:        {G.number_of_nodes()}")
print(f"Total relationships: {G.number_of_edges()}\n")

print("Node counts by type:")
for label, count in node_label_counts.items():
    print(f"  {label}: {count}")

print("\nRelationship counts by type:")
for label, count in edge_label_counts.items():
    print(f"  {label}: {count}")

# Preview a few example nodes and edges
print("\n--- Sample nodes ---")
for n, d in list(G.nodes(data=True))[:5]:
    print(f"{n}: {d}")

print("\n--- Sample edges ---")
for u, v, d in list(G.edges(data=True))[:5]:
    print(f"{u} -> {v}: {d}")
# Out:
# Total nodes:        2429
# Total relationships: 2883
#
# Node counts by type:
#   :Role: 133
#   :Technical skill: 912
#   :Soft skill: 198
#   :Task: 824
#   :Tool: 317
#   :Skill: 2
#   :OSCAOccupation: 43
#
# Relationship counts by type:
#   REQUIRES_SKILL: 1029
#   USES_TOOL: 284
#   PERFORMS_TASK: 749
#   INVOLVES_SKILL: 489
#   REQUIRES_TOOL: 246
#   MATCHED_TO_OSCA: 53
#   REQUIRES_EXPERIENCE: 33
#
# --- Sample nodes ---
# n0: {'labels': ':Role', 'id': 'Analytics And Insights Manager'}
# n1: {'labels': ':Technical skill', 'id': 'Predictive Analytics'}
# n2: {'labels': ':Technical skill', 'id': 'Machine Learning'}
# n3: {'labels': ':Soft skill', 'id': 'Communication'}
# n4: {'labels': ':Soft skill', 'id': 'Project Management'}
#
# --- Sample edges ---
# n0 -> n1: {'label': 'REQUIRES_SKILL'}
# n0 -> n2: {'label': 'REQUIRES_SKILL'}
# n0 -> n3: {'label': 'REQUIRES_SKILL'}
# n0 -> n4: {'label': 'REQUIRES_SKILL'}
# n0 -> n12: {'label': 'USES_TOOL'}

# %%
# --- Save a GraphML Backup in Your Backup Folder ---
import networkx as nx

backup_path = '/content/drive/MyDrive/knowledge-graph-llms/graph_backups/cleaned_graph_after_noise_removal.graphml'
nx.write_graphml(G, backup_path)
print(f"Backup of cleaned graph saved to: {backup_path}")
# Out:
# Backup of cleaned graph saved to: /content/drive/MyDrive/knowledge-graph-llms/graph_backups/cleaned_graph_after_noise_removal.graphml

# %%
role_titles = sorted([d.get('id') for _, d in G.nodes(data=True) if d.get('labels') == ':Role'])
print(f"Total unique roles to review: {len(role_titles)}")
# Optionally, save for manual/LLM review
import pandas as pd
roles_df = pd.DataFrame({'Role': role_titles})
roles_path = '/content/drive/MyDrive/knowledge-graph-llms/role_titles_for_llm_consolidation.csv'
roles_df.to_csv(roles_path, index=False)
print(f"Role list saved for LLM review: {roles_path}")
# Out:
# Total unique roles to review: 133
# Role list saved for LLM review: /content/drive/MyDrive/knowledge-graph-llms/role_titles_for_llm_consolidation.csv

# %%
import pandas as pd

unmatched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/unmatched_roles_for_review.csv'
unmatched_df = pd.read_csv(unmatched_path)
unmatched_roles = sorted(unmatched_df['Our_Role'].dropna().unique())

print(f"Total unmatched roles: {len(unmatched_roles)}")

# Save for LLM review
roles_unmatched_path = '/content/drive/MyDrive/knowledge-graph-llms/unmatched_role_titles_for_llm_consolidation.csv'
pd.DataFrame({'Role': unmatched_roles}).to_csv(roles_unmatched_path, index=False)
print(f"Unmatched roles saved for LLM review: {roles_unmatched_path}")
# Out:
# Total unmatched roles: 118
# Unmatched roles saved for LLM review: /content/drive/MyDrive/knowledge-graph-llms/unmatched_role_titles_for_llm_consolidation.csv

# %% [markdown]
# # Self-contained Python script for semantically driven, seniority-agnostic role consolidation

# %%
# =============================
# 1. Load Cleaned Graph & Matched Roles
# =============================
import networkx as nx
import pandas as pd

# --- Load cleaned graph ---
graph_path = '/content/drive/MyDrive/knowledge-graph-llms/graph_backups/cleaned_graph_after_noise_removal.graphml'
G = nx.read_graphml(graph_path)
print(f"Graph loaded. Total nodes: {G.number_of_nodes()}")

# --- Load matched roles from OSCA mapping ---
matched_path = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/for_graph-update/osca_one_to_one_matched.csv'
matched = pd.read_csv(matched_path)
matched_roles = set(matched['Our_Role'].dropna())

# --- Extract roles (nodes with label ':Role') from graph ---
graph_roles = set(d['id'] for _, d in G.nodes(data=True) if d.get('labels') == ':Role')

# --- Compute unmatched roles ---
unmatched_roles = sorted(graph_roles - matched_roles)

print(f"Total unique :Role nodes in graph: {len(graph_roles)}")
print(f"Total roles matched with OSCA:     {len(matched_roles)}")
print(f"Total unmatched roles for LLM:      {len(unmatched_roles)}")

# --- Optional: Save for review or backup ---
pd.DataFrame({'Role': unmatched_roles}).to_csv(
    '/content/drive/MyDrive/knowledge-graph-llms/unmatched_roles_cleaned_graph.csv',
    index=False
)
print("Saved unmatched role list for LLM review.")
# Out:
# Graph loaded. Total nodes: 2429
# Total unique :Role nodes in graph: 133
# Total roles matched with OSCA:     53
# Total unmatched roles for LLM:      80
# Saved unmatched role list for LLM review.

# %%
import pandas as pd
from openai import OpenAI
import csv
import io

# 1. Load roles from the saved unmatched role list
roles_path = '/content/drive/MyDrive/knowledge-graph-llms/unmatched_roles_cleaned_graph.csv'
roles = pd.read_csv(roles_path)['Role'].dropna().tolist()

# 2. Build the prompt with all roles and few-shot examples
few_shot_examples = """Source_Role|Canonical_Role
Administration Assistant|Administrative Assistant
Administrative Assistant|Administrative Assistant
Bim Coordinator|BIM Professional
Bim Manager|BIM Professional
Bim Specialist|BIM Professional
"""

role_lines = '\n'.join(r for r in roles)
prompt = (
    "You are a workforce classification and ontology expert. Your job is to group construction and built environment job titles that are synonyms, near-synonyms, or variants describing the same core function, regardless of seniority, wording, or local jargon.\n"
    "For each group of synonymous roles, assign a single clear and concise canonical role title. This canonical title should represent the core role, not seniority, location, or organizational context.\n"
    "- Treat “Coordinator” and “Administrator” as equivalent if they serve the same function.\n"
    "- Treat abbreviations, plurals, and singulars as the same (e.g., “BIM Specialist” and “BIM Specialists”).\n"
    "- Merge generic or functionally identical roles, even if worded differently (e.g., “Administration Assistant”, “Administrative Assistant” → “Administrative Assistant”).\n"
    "- If a role does not have an obvious synonym, keep it as its own canonical title.\n"
    "- Ignore differences in level (junior/senior), project/field/site, or small title variants if the underlying job is the same.\n"
    "\nFormat your response as a CSV with two columns, separated by a pipe (`|`): Source_Role|Canonical_Role\n"
    "Do not add any explanation or commentary. Only output the CSV.\n\n"
    "Here are some examples:\n"
    f"{few_shot_examples}\n"
    "Here are the roles to group:\n"
    f"{role_lines}"
)

# 3. Call the LLM (use gpt-4o if available)
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-4o",  # Use 'gpt-4o' or your best available
    messages=[
        {"role": "system", "content": "You are a workforce role ontology expert."},
        {"role": "user", "content": prompt}
    ],
    max_completion_tokens=2000  # Should be plenty for 80 lines of CSV output
)

llm_csv = response.choices[0].message.content.strip()

# 4. Parse output as CSV (pipe delimiter, skip any non-header lines)
reader = csv.reader(io.StringIO(llm_csv), delimiter='|')
rows = [row for row in reader if len(row) == 2 and row[0] != "Source_Role"]

df = pd.DataFrame(rows, columns=["Source_Role", "Canonical_Role"])
output_path = '/content/drive/MyDrive/knowledge-graph-llms/unmatched_roles_canonicalized.csv'
df.to_csv(output_path, index=False)
print(f"Saved canonicalization mapping to: {output_path}")

# Show sample for review
print(df.head(10))
# Out:
# Saved canonicalization mapping to: /content/drive/MyDrive/knowledge-graph-llms/unmatched_roles_canonicalized.csv
#                        Source_Role                   Canonical_Role
# 0         Administration Assistant         Administrative Assistant
# 1         Administrative Assistant         Administrative Assistant
# 2   Analytics And Insights Manager   Analytics And Insights Manager
# 3              Analytics Developer              Analytics Developer
# 4  Artificial Intelligence Manager  Artificial Intelligence Manager
# 5                   Asset Engineer                   Asset Engineer
# 6               Automation Manager               Automation Manager
# 7      Automation Systems Engineer      Automation Systems Engineer
# 8                  Bim Coordinator                 BIM Professional
# 9                      Bim Manager                 BIM Professional

# %%
# ==============================================================================
# 0. SETUP: INSTALL NECESSARY LIBRARIES
# ==============================================================================
# openpyxl is required by pandas to read .xlsx files.
# !pip install openpyxl --quiet
print("Setup complete. Libraries installed.")

# ==============================================================================
# 1. PREPARATION: IMPORTS AND GOOGLE DRIVE SETUP
# ==============================================================================
import pandas as pd
import networkx as nx
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')
print("Google Drive mounted successfully.")

# ==============================================================================
# 2. LOAD GRAPH AND CURATED MAPPING FILE
# ==============================================================================
# --- Define file paths ---
graph_path = '/content/drive/MyDrive/knowledge-graph-llms/graph_backups/cleaned_graph_after_noise_removal.graphml'
mapping_file = '/content/drive/MyDrive/knowledge-graph-llms/analysis_without_neo4j/Curated_Canonical_Role.xlsx'
output_graph_path = '/content/drive/MyDrive/knowledge-graph-llms/graph_backups/graph_after_canonical_merge.graphml'

# --- Load graph ---
try:
    G = nx.read_graphml(graph_path)
    print(f"Graph loaded successfully. Total nodes: {G.number_of_nodes()}, Total edges: {G.number_of_edges()}.")
except FileNotFoundError:
    print(f"ERROR: Graph file not found at {graph_path}")
    # Stop execution if the graph isn't found
    exit()

# --- Load curated mapping file ---
try:
    df = pd.read_excel(mapping_file)
    print(f"Loaded {len(df)} role mapping rows from Excel file.")
except FileNotFoundError:
    print(f"ERROR: Mapping file not found at {mapping_file}")
    # Stop execution if the mapping isn't found
    exit()

# ==============================================================================
# 3. EXPERT FIX: CREATE A HIGH-PERFORMANCE LOOKUP INDEX
# This is the performance fix. Instead of searching the whole graph for each
# role, we build a dictionary once for instantaneous lookups.
# ==============================================================================
role_id_to_node_key = {
    d.get('id'): n
    for n, d in G.nodes(data=True)
    if d.get('labels') == ':Role' and d.get('id') is not None
}
print(f"Created high-performance lookup index for {len(role_id_to_node_key)} roles.")

# ==============================================================================
# 4. BUILD MERGE GROUPS
# This logic was correct and remains the same. It groups source roles by their
# target canonical role.
# ==============================================================================
merge_map = {}
for _, row in df.iterrows():
    src = row['Source_Role'].strip()
    canon = row['Curated_Canonical_Role'].strip()
    if canon not in merge_map:
        merge_map[canon] = []
    merge_map[canon].append(src)
print(f"Built {len(merge_map)} consolidation groups.")

# ==============================================================================
# 5. MERGE NODES WITH CORRECT AND ROBUST LOGIC
# This section contains the critical fixes for both performance and correctness.
# ==============================================================================
print("\nStarting node consolidation process...")
total_merged_nodes = 0

for canon_role, src_roles in merge_map.items():
    # Use the high-performance index to get node keys
    node_keys = [role_id_to_node_key.get(role_name) for role_name in src_roles if role_name in role_id_to_node_key]

    # Skip if no nodes were found (e.g., roles already merged/deleted)
    if not node_keys:
        print(f"INFO: No graph nodes found for merge group: {src_roles} -> {canon_role}. Skipping.")
        continue

    # Skip if there's only one node and it's already the canonical one.
    # This handles cases where a role is its own canonical role.
    if len(node_keys) <= 1 and src_roles[0] == canon_role:
      continue

    # The first node in the list becomes the 'survivor' that others merge into
    survivor_key = node_keys[0]
    nodes_to_merge = node_keys[1:]

    # EXPERT FIX: To prevent data loss, we must check for existing relationships
    # based not just on the connected nodes, but on the relationship's full data
    # (type, properties, etc.). We create sets of edge "fingerprints".
    survivor_out_edges = {(target, frozenset(data.items())) for _, target, data in G.out_edges(survivor_key, data=True)}
    survivor_in_edges = {(source, frozenset(data.items())) for source, _, data in G.in_edges(survivor_key, data=True)}

    # Merge all relationships from other nodes into the survivor
    for key_to_merge in nodes_to_merge:
        # Copy outgoing edges, preventing duplicates
        for _, target, data in list(G.out_edges(key_to_merge, data=True)):
            edge_fingerprint = (target, frozenset(data.items()))
            if edge_fingerprint not in survivor_out_edges:
                G.add_edge(survivor_key, target, **data)
                survivor_out_edges.add(edge_fingerprint)

        # Copy incoming edges, preventing duplicates
        for source, _, data in list(G.in_edges(key_to_merge, data=True)):
            edge_fingerprint = (source, frozenset(data.items()))
            if edge_fingerprint not in survivor_in_edges:
                G.add_edge(source, survivor_key, **data)
                survivor_in_edges.add(edge_fingerprint)

        # Remove the now-merged node
        G.remove_node(key_to_merge)
        total_merged_nodes += 1

    # Finally, update the survivor's 'id' to the canonical role name
    G.nodes[survivor_key]['id'] = canon_role
    print(f"SUCCESS: Merged {len(nodes_to_merge)} role(s) into '{canon_role}'.")

print(f"\nConsolidation complete. Total nodes merged away: {total_merged_nodes}.")

# ==============================================================================
# 6. SAVE UPDATED GRAPH
# ==============================================================================
nx.write_graphml(G, output_graph_path)
print(f"\nSaved updated graph after consolidation to: {output_graph_path}")

# ==============================================================================
# 7. FINAL VERIFICATION
# ==============================================================================
# Check: Print all remaining Role nodes to confirm the consolidation
role_nodes = sorted([d['id'] for _, d in G.nodes(data=True) if d.get('labels') == ':Role'])
print(f"\nVerification complete. Total remaining unique :Role nodes: {len(role_nodes)}")
print("Sample of final canonical roles:", role_nodes[:20])
# Out:
# Setup complete. Libraries installed.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted successfully.
# Graph loaded successfully. Total nodes: 2429, Total edges: 2883.
# Loaded 80 role mapping rows from Excel file.
# Created high-performance lookup index for 133 roles.
# Built 56 consolidation groups.
#
# Starting node consolidation process...
# SUCCESS: Merged 2 role(s) into 'Administrative Assistant'.
# SUCCESS: Merged 2 role(s) into 'Analytics And Insights Manager'.
# SUCCESS: Merged 1 role(s) into 'Asset Engineer'.
# SUCCESS: Merged 2 role(s) into 'Automation Systems Engineer'.
# SUCCESS: Merged 2 role(s) into 'BIM Professional'.
# SUCCESS: Merged 6 role(s) into 'Project Engineer'.
# SUCCESS: Merged 1 role(s) into 'Human Resources And Safety Manager'.
# SUCCESS: Merged 2 role(s) into 'Safety Advisor'.
# SUCCESS: Merged 0 role(s) into 'IOT Software Engineer'.
# SUCCESS: Merged 0 role(s) into 'ICT Support Team Leader'.
# SUCCESS: Merged 1 role(s) into 'Planner'.
# SUCCESS: Merged 2 role(s) into 'Procurement Manager'.
# SUCCESS: Merged 0 role(s) into 'Data Scientist'.
# SUCCESS: Merged 2 role(s) into 'Talent Sourcing Analyst'.
# SUCCESS: Merged 1 role(s) into 'Workplace Experience Manager'.
#
# Consolidation complete. Total nodes merged away: 24.
#
# Saved updated graph after consolidation to: /content/drive/MyDrive/knowledge-graph-llms/graph_backups/graph_after_canonical_merge.graphml
#
# Verification complete. Total remaining unique :Role nodes: 109
# Sample of final canonical roles: ['Administrative Assistant', 'Analytics And Insights Manager', 'Analytics Developer', 'Area Manager', 'Artificial Intelligence Manager', 'Asset Engineer', 'Automation Manager', 'Automation Systems Engineer', 'Automation Technician', 'BIM Professional', 'Business Governance Manager', 'Business Intelligence Developer', 'Catering Coordinator', 'Cloud Infrastructure Engineer', 'Commissioning Manager', 'Communications Technician', 'Completions Engineer', 'Construction Superintendent', 'Contracts Administrator', 'Control Systems Engineer']

# %%
# ==============================================================================
# 0. SETUP: INSTALL NECESSARY LIBRARIES
# ==============================================================================
# No new libraries are needed if you are running this in the same session.
# This is here for completeness if you run it in a new notebook.
# !pip install pandas networkx openpyxl --quiet
print("Setup complete.")

# ==============================================================================
# 1. PREPARATION: IMPORTS AND GOOGLE DRIVE SETUP
# ==============================================================================
import pandas as pd
import networkx as nx
from collections import Counter
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')
print("Google Drive mounted successfully.")

# ==============================================================================
# 2. LOAD THE FINAL CONSOLIDATED GRAPH
# ==============================================================================
# --- Define the final graph file path ---
final_graph_path = '/content/drive/MyDrive/knowledge-graph-llms/graph_backups/graph_after_canonical_merge.graphml'

# --- Load graph with error handling ---
try:
    G = nx.read_graphml(final_graph_path)
    print(f"Final consolidated graph loaded successfully from: {final_graph_path}")
except FileNotFoundError:
    print(f"ERROR: Graph file not found at {final_graph_path}")
    # Stop execution if the graph isn't found
    exit()

# ==============================================================================
# 3. GENERATE THE GRAPH ASSESSMENT REPORT
# ==============================================================================
print("\n" + "="*50)
print("KNOWLEDGE GRAPH ASSESSMENT REPORT")
print("="*50)

# --- Overall Statistics ---
print("\n--- I. Overall Graph Statistics ---")
print(f"Total Number of Nodes: {G.number_of_nodes()}")
print(f"Total Number of Edges (Relationships): {G.number_of_edges()}")

# --- Node Type Breakdown ---
print("\n--- II. Node Type Analysis (Labels) ---")
# Use collections.Counter for an efficient way to count hashable items
node_labels = [d.get('labels', 'Unknown') for _, d in G.nodes(data=True)]
node_counts = Counter(node_labels)

print(f"{'Node Label':<25} | {'Count'}")
print("-" * 40)
for label, count in sorted(node_counts.items()):
    print(f"{label:<25} | {count}")

# --- Relationship Type Breakdown ---
print("\n--- III. Relationship Type Analysis (Labels) ---")
edge_labels = [d.get('label', 'Unknown') for _, _, d in G.edges(data=True)]
edge_counts = Counter(edge_labels)

print(f"{'Relationship Label':<25} | {'Count'}")
print("-" * 40)
for label, count in sorted(edge_counts.items()):
    print(f"{label:<25} | {count}")


# --- Specific Sanity Checks ---
print("\n--- IV. Specific Role Count Verification ---")
# Verify the final number of canonical roles
role_count = node_counts.get(':Role', 0)
print(f"Canonical Project Roles (:Role): {role_count}")
if role_count == 109:
    print("  -> VERIFIED: Count matches the expected outcome of consolidation.")
else:
    print(f"  -> WARNING: Count ({role_count}) does not match the expected 109.")

# Verify the number of OSCA roles
osca_role_count = node_counts.get(':OSCAOccupation', 0)
print(f"Standard OSCA Roles (:OSCAOccupation): {osca_role_count}")
if osca_role_count == 43:
    print("  -> VERIFIED: Count matches the expected number of unique OSCA roles.")
else:
    print(f"  -> WARNING: Count ({osca_role_count}) does not match the expected 43.")

print("\n" + "="*50)
print("End of Report")
print("="*50)
# Out:
# Setup complete.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted successfully.
# Final consolidated graph loaded successfully from: /content/drive/MyDrive/knowledge-graph-llms/graph_backups/graph_after_canonical_merge.graphml
#
# ==================================================
# KNOWLEDGE GRAPH ASSESSMENT REPORT
# ==================================================
#
# --- I. Overall Graph Statistics ---
# Total Number of Nodes: 2405
# Total Number of Edges (Relationships): 2829
#
# --- II. Node Type Analysis (Labels) ---
# Node Label                | Count
# ----------------------------------------
# :OSCAOccupation           | 43
# :Role                     | 109
# :Skill                    | 2
# :Soft skill               | 198
# :Task                     | 824
# :Technical skill          | 912
# :Tool                     | 317
#
# --- III. Relationship Type Analysis (Labels) ---
# Relationship Label        | Count
# ----------------------------------------
# INVOLVES_SKILL            | 488
# MATCHED_TO_OSCA           | 53
# PERFORMS_TASK             | 736
# REQUIRES_EXPERIENCE       | 33
# REQUIRES_SKILL            | 996
# REQUIRES_TOOL             | 246
# USES_TOOL                 | 277
#
# --- IV. Specific Role Count Verification ---
# Canonical Project Roles (:Role): 109
#   -> VERIFIED: Count matches the expected outcome of consolidation.
# Standard OSCA Roles (:OSCAOccupation): 43
#   -> VERIFIED: Count matches the expected number of unique OSCA roles.
#
# ==================================================
# End of Report
# ==================================================
